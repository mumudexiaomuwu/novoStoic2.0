# %%
import requests
from Bio import SeqIO
from Bio.KEGG import REST
from Bio.KEGG import Enzyme
# %matplotlib inline
from IPython.display import Image
import io
import os
import pandas as pd
from Bio.KEGG.KGML import KGML_parser
from Bio.Graphics.KGML_vis import KGMLCanvas
from tqdm import tqdm
import json

# %%
def get_ncbi_protein_id(kegg_gene_id):
    base_url = "http://rest.kegg.jp"
    get_conv_url = f"{base_url}/conv/ncbi-proteinid/{kegg_gene_id}"
    #ncbi_protein_ids = []
    response = requests.get(get_conv_url)
    if response.status_code != 200:
        #print(f"Conversoin of Kegg ID to NCBI gene id failed (status code: {response.status_code})")
        return 'Nothing'
    for line in response.text.splitlines():
            #print(line)
            parts = line.split()
            #print(parts)
            if len(parts)==0:
                return 'Nothing'
            return parts[1]
            #print(parts[1])
            #ncbi_protein_ids.append(parts[1])

# %%
def get_uniprot_id(kegg_gene_id):
    base_url = "http://rest.kegg.jp"
    get_conv_url = f"{base_url}/conv/uniprot/{kegg_gene_id}"
    #ncbi_protein_ids = []
    response = requests.get(get_conv_url)
    if response.status_code != 200:
        #print(f"Conversoin of Kegg ID to NCBI gene id failed (status code: {response.status_code})")
        gene_id=kegg_gene_id.split(':')[1]
        get_conv_url = f"{base_url}/conv/uniprot/ncbi-proteinid:{kegg_gene_id}"
        response = requests.get(get_conv_url)
        if response.status_code != 200:
            return 'Nothing'
    for line in response.text.splitlines():
            #print(line)
            parts = line.split()
            #print(parts)
            if len(parts)==0:
                return 'Nothing'
            return parts[1]
            #print(parts[1])
            #ncbi_protein_ids.append(parts[1])

# %%
def get_protein_sequence(uniprot_id):
    """
    Fetches the amino acid sequence of a protein from UniProt.

    Args:
        uniprot_id (str): The UniProt ID of the protein.

    Returns:
        str: The amino acid sequence of the protein, or None if not found.
    """

    url = f'https://www.uniprot.org/uniprot/{uniprot_id}.fasta'
    response = requests.get(url)

    if response.status_code == 200:
        # Separate header from sequence
        header, sequence = response.text.split('\n', 1)
        return sequence.replace('\n', '')  # Remove newlines
    else:
        print(f"Protein not found (UniProt ID: {uniprot_id})")
        return None

# Example usage
#uniprot_id = "P01308"  # Example: Human Insulin
'''
uniprot_id = "G1JUH1"
sequence = get_protein_sequence(uniprot_id)

if sequence:
    print(sequence)
'''
# Out:
# '\nuniprot_id = "G1JUH1"\nsequence = get_protein_sequence(uniprot_id)\n\nif sequence:\n    print(sequence)\n'

# %%
def get_uniprot_ids_from_rhea_id(rhea_id):
    """
    Fetches a list of UniProt IDs associated with a Rhea reaction ID.

    Args:
        rhea_id: The Rhea reaction ID as a string (e.g., "RHEA:10000").

    Returns:
        A list of UniProt IDs, or None if an error occurs.
    """

    url= "https://rest.uniprot.org/uniprotkb/search?"
    rid = rhea_id.split(':')[1]

    parameter = {"query":'((cc_catalytic_activity:"rhea:"'+rid+') AND (fragment:false) AND (reviewed:true))',
        #"query":'((cc_catalytic_activity:"rhea:"'+rid+') AND (fragment:false) AND (reviewed:false))',
        #"query":'(cc_catalytic_activity:"rhea:"'+rid+')',
        "fields":"accession,rhea",
        "format":'tsv',
    }
    response = requests.get(url,params=parameter)
    #print(response.content)

   
    data = response.text.strip()

    # Check if the response has multiple lines (i.e., multiple UniProt IDs)
    if '\n' in data:
        uniprot_ids = data.splitlines()[1:]  # Skip the header line
    else:
        uniprot_ids = [data] if data else []

    return uniprot_ids

# %%
def get_gene_sequences_from_rhea_reaction(all_rhea_ids, rule_id):
    sequences = []
    all_uniprot_ids = []
    print("__________")
    for each_rhea_id in all_rhea_ids:
        uniprot_ids = get_uniprot_ids_from_rhea_id('rhea:'+each_rhea_id)
        print(each_rhea_id)
        print(uniprot_ids)
        if uniprot_ids:
            #print("UniProt IDs for", each_rhea_id)
            #print(len(uniprot_ids))
            for uniprot_id in uniprot_ids:
                p = ["uniprot_id:"+uniprot_id.split('\t')[0],get_protein_sequence(uniprot_id.split('\t')[0])]
                if uniprot_id.split('\t')[0]!='Entry' and uniprot_id.split('\t')[0] not in all_uniprot_ids:
                    #print(uniprot_id.split('\t')[0])
                    sequences.append(p)
                    #seq_record[each_rhea_id]=p
        #print("----------")
        #print(seq_record)
    return sequences

# %%
def get_gene_sequences_from_kegg_reaction(all_kegg_ids, rule_id):
    """
    Retrieves gene sequences associated with a KEGG reaction ID using the KEGG REST API.

    Args:
        reaction_id (str): The KEGG reaction ID (e.g., "R00001").

    Returns:
        list: A list of Biopython SeqRecord objects containing the gene sequences.
        
    """
    all_gene_ids_unique = []
    sequences = []
    all_ko_ids = []
    for reaction_id in all_kegg_ids:
        print(reaction_id)
        base_url = "http://rest.kegg.jp"

        # 1. Get EC number linked to the reaction
        get_ec_url = f"{base_url}/link/enzyme/{reaction_id}"
        response = requests.get(get_ec_url)
        print(get_ec_url)
        if response.status_code != 200:
            print(f"KEGG API request failed for EC number (status code: {response.status_code})")
            return []
            #raise ValueError(f"KEGG API request failed (status code: {response.status_code

        ec_numbers = []
        for line in response.text.splitlines():
            parts = line.split()
            ec_number = parts[1]  # EC number is in the second column
            ec_numbers.append(ec_number)

        # 2. Get KO number(Orthology number) linked to the EC number
        get_ko_url = f"{base_url}/link/ko/{ec_numbers[0]}"
        print(get_ko_url)
        response = requests.get(get_ko_url)

        if response.status_code != 200:
            print(f"KEGG API request failed for KO (status code: {response.status_code})")
            return []
        ko_ids = []
        
        for line in response.text.splitlines():
            parts = line.split()
            ko_id = parts[1].split(':')[1]
            if ko_id not in all_ko_ids:
                all_ko_ids.append(ko_id)

                # 3. For each KO number extracted, now extracting gene id for that KO number

                get_genes_url = f"{base_url}/link/genes/{ko_id}"
                print(get_genes_url)
                response = requests.get(get_genes_url)
                if response.status_code != 200:
                    print(f"KEGG API request failed for KO (status code: {response.status_code})")
                    return []

                gene_ids = []
                for line in response.text.splitlines():
                    parts = line.split()
                    gene_id = parts[1]

                    # 4. Adding only the genes which are not extracted before

                    if gene_id not in all_gene_ids_unique:
                        gene_ids.append(gene_id)
                        all_gene_ids_unique.append(gene_id)

                # 5. Fetch gene sequence data from each gene id

                for gene_id in gene_ids:
                    get_gene_url = f"{base_url}/get/{gene_id}/aaseq"
                    response = requests.get(get_gene_url)

                    if response.status_code != 200:
                        print(f"Warning: Failed to retrieve sequence for gene {gene_id}")
                        continue
                    itr = 0
                    seq_record = ''
                    for line in response.text.splitlines():
                        itr+=1
                        parts = line.split()
                        #print(itr)
                        if itr>1:
                            seq_record += parts[0]
                    record = ["kegg:"+gene_id.split(':')[0]]
                    record.append("ncbi_gene_id:"+gene_id.split(':')[1])
                    print(gene_id)
                    ncbi_protein_id = get_ncbi_protein_id(gene_id)
                    uniprot_id = get_uniprot_id(gene_id)
                    if ncbi_protein_id!='Nothing':
                        record.append("ncbi_protein_id:"+ncbi_protein_id.split(':')[1])
                    if uniprot_id!='Nothing':
                        record.append("uniprot_id:"+uniprot_id.split(':')[1])
                    print(record)
                    record.append(seq_record)
                    sequences.append(record)
                    #print(record)
                    '''
                    with open(f"{rule_id}_genes_{ko_ids[p]}.json", "w") as outfile: 
                        json.dump({reaction_id:sequences}, outfile)
                    '''
        
    
    return sequences

# %%
all_refs_in_all_rules = json.load(open('./all_refs_in_all_rules.json'))

# %%
all_refs_in_all_rules['MNXR102311']
# Out:
# {'kegg': ['R05552'],
#  'rhea': [],
#  'sabio': ['5157'],
#  'metacyc': [],
#  'seed': ['rxn03840'],
#  'bigg': ['PABB', 'R_PABB']}

# %%
all_refs_in_all_rules['MNXR114039']
# Out:
# {'kegg': ['R10721'],
#  'rhea': ['41432', '41433', '41434', '41435'],
#  'sabio': ['12171', '6632', '6679'],
#  'metacyc': ['RXN-15302'],
#  'seed': ['rxn40455'],
#  'bigg': []}

# %%
all_refs_in_all_rules['MNXR100024']
# Out:
# {'kegg': ['R00253', 'R00482', 'R02711', 'R05030', 'R00483'],
#  'rhea': ['16169',
#   '16170',
#   '16171',
#   '16172',
#   '14197',
#   '14198',
#   '14199',
#   '14200',
#   '13853',
#   '13854',
#   '13855',
#   '13856',
#   '11372',
#   '11373',
#   '11374',
#   '11375'],
#  'sabio': ['760'],
#  'metacyc': ['GLUTAMINESYN-RXN',
#   '6.3.1.4-RXN',
#   '4-METHYLENEGLUTAMATE--AMMONIA-LIGASE-RXN',
#   'RXN-11338',
#   'ASNSYNA-RXN'],
#  'seed': ['rxn00187',
#   'rxn19835',
#   'rxn19836',
#   'rxn30022',
#   'rxn33952',
#   'rxn33953',
#   'rxn34791',
#   'rxn34792',
#   'rxn00339',
#   'rxn44379',
#   'rxn01956',
#   'rxn46144',
#   'rxn21649',
#   'rxn03407',
#   'rxn30313',
#   'rxn00340',
#   'rxn29993'],
#  'bigg': ['GALh',
#   'GALm',
#   'GLNS',
#   'GLNS_1',
#   'R_GALh',
#   'R_GALm',
#   'R_GLNS',
#   'R_GLNS_1',
#   'ASNS3',
#   'R_ASNS3',
#   'ASNS2',
#   'R_ASNS2']}

# %%
rule_id = "MNXR100024"

# %%
sequences_from_rhea = get_gene_sequences_from_rhea_reaction(all_refs_in_all_rules[rule_id]['rhea'], rule_id)

# %%
sequences_from_kegg = get_gene_sequences_from_kegg_reaction(all_refs_in_all_rules[rule_id]['kegg'], rule_id)
# Out:
# R00253
# http://rest.kegg.jp/link/enzyme/R00253
# http://rest.kegg.jp/link/ko/ec:6.3.1.2
# http://rest.kegg.jp/link/genes/K01915
# hsa:2752
# ['kegg:hsa', 'ncbi_gene_id:2752', 'ncbi_protein_id:NP_001028216', 'uniprot_id:P15104']
# ptr:456450
# ['kegg:ptr', 'ncbi_gene_id:456450', 'ncbi_protein_id:NP_001266714', 'uniprot_id:G2HER6']
# pps:100975375
# ['kegg:pps', 'ncbi_gene_id:100975375', 'ncbi_protein_id:XP_003824783', 'uniprot_id:A0A2R9CBD9']
# ggo:101154019
# ['kegg:ggo', 'ncbi_gene_id:101154019', 'ncbi_protein_id:XP_004028058', 'uniprot_id:G3SJV7']
# pon:100452390
# ['kegg:pon', 'ncbi_gene_id:100452390', 'ncbi_protein_id:XP_002809762', 'uniprot_id:A0A2J8V806']
# nle:100602624
# ['kegg:nle', 'ncbi_gene_id:100602624', 'ncbi_protein_id:XP_030674647']
# hmh:116458010
# ['kegg:hmh', 'ncbi_gene_id:116458010', 'ncbi_protein_id:XP_031993425']
# mcc:715952
# ['kegg:mcc', 'ncbi_gene_id:715952', 'ncbi_protein_id:NP_001252942', 'uniprot_id:F7CAM5']
# mcf:101926704
# ['kegg:mcf', 'ncbi_gene_id:101926704', 'ncbi_protein_id:XP_005540219', 'uniprot_id:A0A7N9CVE9']
# mthb:126940476
# ['kegg:mthb', 'ncbi_gene_id:126940476', 'ncbi_protein_id:XP_050622349']
# mni:105484548
# ['kegg:mni', 'ncbi_gene_id:105484548', 'ncbi_protein_id:XP_011744567', 'uniprot_id:A0A2K6B8J1']
# csab:103230475
# ['kegg:csab', 'ncbi_gene_id:103230475', 'ncbi_protein_id:XP_007987475', 'uniprot_id:A0A0D9RJ85']
# caty:105586524
# ['kegg:caty', 'ncbi_gene_id:105586524', 'ncbi_protein_id:XP_011917015']
# caty:105580432
# ['kegg:caty', 'ncbi_gene_id:105580432', 'ncbi_protein_id:XP_011903918']
# panu:101015190
# ['kegg:panu', 'ncbi_gene_id:101015190', 'ncbi_protein_id:XP_021785529']
# tge:112632665
# ['kegg:tge', 'ncbi_gene_id:112632665', 'ncbi_protein_id:XP_025254294']
# mleu:105534205
# ['kegg:mleu', 'ncbi_gene_id:105534205', 'ncbi_protein_id:XP_011828283']
# rro:104666784
# ['kegg:rro', 'ncbi_gene_id:104666784', 'ncbi_protein_id:XP_010367212', 'uniprot_id:A0A2K6RAS0']
# rbb:108512715
# ['kegg:rbb', 'ncbi_gene_id:108512715', 'ncbi_protein_id:XP_017703555']
# tfn:117099022
# ['kegg:tfn', 'ncbi_gene_id:117099022', 'ncbi_protein_id:XP_033094080']
# tfn:117075840
# ['kegg:tfn', 'ncbi_gene_id:117075840', 'ncbi_protein_id:XP_033054472']
# pteh:111536959
# ['kegg:pteh', 'ncbi_gene_id:111536959', 'ncbi_protein_id:XP_023059273']
# cang:105511905
# ['kegg:cang', 'ncbi_gene_id:105511905', 'ncbi_protein_id:XP_011797511', 'uniprot_id:A0A2K5HMA6']
# cjc:100405813
# ['kegg:cjc', 'ncbi_gene_id:100405813', 'ncbi_protein_id:XP_035135650']
# sbq:101040323
# ['kegg:sbq', 'ncbi_gene_id:101040323', 'ncbi_protein_id:XP_003925362', 'uniprot_id:A0A2K6V6L3']
# cimi:108301335
# ['kegg:cimi', 'ncbi_gene_id:108301335', 'ncbi_protein_id:XP_017379965']
# csyr:103276955
# ['kegg:csyr', 'ncbi_gene_id:103276955', 'ncbi_protein_id:XP_008072592', 'uniprot_id:A0A1U7V4G3']
# csyr:103259710
# ['kegg:csyr', 'ncbi_gene_id:103259710', 'ncbi_protein_id:XP_008055551', 'uniprot_id:A0A1U7TP58']
# mmur:105854947
# ['kegg:mmur', 'ncbi_gene_id:105854947', 'ncbi_protein_id:XP_012591032', 'uniprot_id:A0A8B7EA96']
# lcat:123626908
# ['kegg:lcat', 'ncbi_gene_id:123626908', 'ncbi_protein_id:XP_045392104']
# pcoq:105806788
# ['kegg:pcoq', 'ncbi_gene_id:105806788', 'ncbi_protein_id:XP_012495445']
# oga:100964656
# ['kegg:oga', 'ncbi_gene_id:100964656', 'ncbi_protein_id:XP_023366576']
# mmu:14645
# ['kegg:mmu', 'ncbi_gene_id:14645', 'ncbi_protein_id:NP_032157', 'uniprot_id:P15105']
# mcal:110296271
# ['kegg:mcal', 'ncbi_gene_id:110296271', 'ncbi_protein_id:XP_021020545', 'uniprot_id:A0A6P5Q244']
# mpah:110321391
# ['kegg:mpah', 'ncbi_gene_id:110321391', 'ncbi_protein_id:XP_021053279']
# rno:24957
# ['kegg:rno', 'ncbi_gene_id:24957', 'ncbi_protein_id:NP_058769', 'uniprot_id:P09606']
# mcoc:116101519
# ['kegg:mcoc', 'ncbi_gene_id:116101519', 'ncbi_protein_id:XP_031240922']
# anu:117716160
# ['kegg:anu', 'ncbi_gene_id:117716160', 'ncbi_protein_id:XP_034368991']
# mun:110546187
# ['kegg:mun', 'ncbi_gene_id:110546187', 'ncbi_protein_id:XP_021488531']
# cge:100689337
# ['kegg:cge', 'ncbi_gene_id:100689337', 'ncbi_protein_id:NP_001233699', 'uniprot_id:P04773']
# cge:100764163
# ['kegg:cge', 'ncbi_gene_id:100764163', 'ncbi_protein_id:XP_027273149', 'uniprot_id:A0A9J7JS16']
# maua:101825830
# ['kegg:maua', 'ncbi_gene_id:101825830', 'ncbi_protein_id:XP_040594859']
# prob:127223425
# ['kegg:prob', 'ncbi_gene_id:127223425', 'ncbi_protein_id:XP_051041958']
# pleu:114708497
# ['kegg:pleu', 'ncbi_gene_id:114708497', 'ncbi_protein_id:XP_028747656']
# morg:121455041
# ['kegg:morg', 'ncbi_gene_id:121455041', 'ncbi_protein_id:XP_041518487']
# mfot:126493277
# ['kegg:mfot', 'ncbi_gene_id:126493277', 'ncbi_protein_id:XP_049986194']
# mfot:126497367
# ['kegg:mfot', 'ncbi_gene_id:126497367', 'ncbi_protein_id:XP_049991314']
# aamp:119827697
# ['kegg:aamp', 'ncbi_gene_id:119827697', 'ncbi_protein_id:XP_038205460']
# aamp:119807190
# ['kegg:aamp', 'ncbi_gene_id:119807190', 'ncbi_protein_id:XP_041910470']
# aamp:119810096
# ['kegg:aamp', 'ncbi_gene_id:119810096', 'ncbi_protein_id:XP_038179349']
# ngi:103738493
# ['kegg:ngi', 'ncbi_gene_id:103738493', 'ncbi_protein_id:XP_008836724', 'uniprot_id:A0A8C6R255']
# hgl:101696542
# ['kegg:hgl', 'ncbi_gene_id:101696542', 'ncbi_protein_id:XP_004835926']
# hgl:101703275
# ['kegg:hgl', 'ncbi_gene_id:101703275', 'ncbi_protein_id:XP_004853410']
# cpoc:100715062
# ['kegg:cpoc', 'ncbi_gene_id:100715062', 'ncbi_protein_id:XP_003474907', 'uniprot_id:A0A286XGB6']
# ccan:109699371
# ['kegg:ccan', 'ncbi_gene_id:109699371', 'ncbi_protein_id:XP_020039613', 'uniprot_id:A0A250YGY6']
# dord:105985244
# ['kegg:dord', 'ncbi_gene_id:105985244', 'ncbi_protein_id:XP_012871142', 'uniprot_id:A0A1S3F5N0']
# dsp:122103673
# ['kegg:dsp', 'ncbi_gene_id:122103673', 'ncbi_protein_id:XP_042530169']
# plop:125359085
# ['kegg:plop', 'ncbi_gene_id:125359085', 'ncbi_protein_id:XP_048212550']
# ncar:124961581
# ['kegg:ncar', 'ncbi_gene_id:124961581', 'ncbi_protein_id:XP_047376280']
# mmma:107147322
# ['kegg:mmma', 'ncbi_gene_id:107147322', 'ncbi_protein_id:XP_015347217', 'uniprot_id:A0A8C5ZM72']
# ocu:100359274
# ['kegg:ocu', 'ncbi_gene_id:100359274', 'ncbi_protein_id:XP_051696932']
# opi:101520151
# ['kegg:opi', 'ncbi_gene_id:101520151', 'ncbi_protein_id:XP_004578892']
# tup:102491090
# ['kegg:tup', 'ncbi_gene_id:102491090', 'ncbi_protein_id:XP_006142384']
# gvr:103601441
# ['kegg:gvr', 'ncbi_gene_id:103601441', 'ncbi_protein_id:XP_008584071']
# gvr:103601826
# ['kegg:gvr', 'ncbi_gene_id:103601826', 'ncbi_protein_id:XP_008584462']
# cfa:403443
# ['kegg:cfa', 'ncbi_gene_id:403443', 'ncbi_protein_id:NP_001280153', 'uniprot_id:Q8HZM5']
# cfa:612295
# ['kegg:cfa', 'ncbi_gene_id:612295', 'ncbi_protein_id:XP_038320536']
# clud:112648465
# ['kegg:clud', 'ncbi_gene_id:112648465', 'ncbi_protein_id:XP_025285797']
# clud:112655053
# ['kegg:clud', 'ncbi_gene_id:112655053', 'ncbi_protein_id:XP_035567721']
# vvp:112921798
# ['kegg:vvp', 'ncbi_gene_id:112921798', 'ncbi_protein_id:XP_025856919', 'uniprot_id:A0A3Q7SAL0']
# vlg:121483123
# ['kegg:vlg', 'ncbi_gene_id:121483123', 'ncbi_protein_id:XP_041597333']
# vlg:121488073
# ['kegg:vlg', 'ncbi_gene_id:121488073', 'ncbi_protein_id:XP_041606275']
# vlg:121496472
# ['kegg:vlg', 'ncbi_gene_id:121496472', 'ncbi_protein_id:XP_041620738']
# npo:129505937
# ['kegg:npo', 'ncbi_gene_id:129505937', 'ncbi_protein_id:XP_055175277']
# npo:129509969
# ['kegg:npo', 'ncbi_gene_id:129509969', 'ncbi_protein_id:XP_055181868']
# npo:129518458
# ['kegg:npo', 'ncbi_gene_id:129518458', 'ncbi_protein_id:XP_055194570']
# aml:100466733
# ['kegg:aml', 'ncbi_gene_id:100466733', 'ncbi_protein_id:XP_011223503', 'uniprot_id:D2HBW5']
# umr:103672426
# ['kegg:umr', 'ncbi_gene_id:103672426', 'ncbi_protein_id:XP_008699345', 'uniprot_id:A0A384CXY2']
# uah:113262718
# ['kegg:uah', 'ncbi_gene_id:113262718', 'ncbi_protein_id:XP_026364959']
# uar:123801396
# ['kegg:uar', 'ncbi_gene_id:123801396', 'ncbi_protein_id:XP_045667355']
# elk:111150722
# ['kegg:elk', 'ncbi_gene_id:111150722', 'ncbi_protein_id:XP_022363984', 'uniprot_id:A0A2Y9JWS6']
# llv:125085799
# ['kegg:llv', 'ncbi_gene_id:125085799', 'ncbi_protein_id:XP_047560525']
# llv:125079893
# ['kegg:llv', 'ncbi_gene_id:125079893', 'ncbi_protein_id:XP_047549570']
# llv:125098725
# ['kegg:llv', 'ncbi_gene_id:125098725', 'ncbi_protein_id:XP_047583746']
# mpuf:101678318
# ['kegg:mpuf', 'ncbi_gene_id:101678318', 'ncbi_protein_id:XP_004767960', 'uniprot_id:M3YJB2']
# mnp:132008423
# ['kegg:mnp', 'ncbi_gene_id:132008423', 'ncbi_protein_id:XP_059242993']
# mnp:132025439
# ['kegg:mnp', 'ncbi_gene_id:132025439', 'ncbi_protein_id:XP_059268702']
# mlk:131814422
# ['kegg:mlk', 'ncbi_gene_id:131814422', 'ncbi_protein_id:XP_059001315']
# mlk:131825500
# ['kegg:mlk', 'ncbi_gene_id:131825500', 'ncbi_protein_id:XP_059020988']
# nvs:122918595
# ['kegg:nvs', 'ncbi_gene_id:122918595', 'ncbi_protein_id:XP_044123175']
# nvs:122913694
# ['kegg:nvs', 'ncbi_gene_id:122913694', 'ncbi_protein_id:XP_044116274']
# oro:101380662
# ['kegg:oro', 'ncbi_gene_id:101380662', 'ncbi_protein_id:XP_004396916', 'uniprot_id:A0A2U3VP72']
# eju:114222813
# ['kegg:eju', 'ncbi_gene_id:114222813', 'ncbi_protein_id:XP_027977271']
# zca:113932044
# ['kegg:zca', 'ncbi_gene_id:113932044', 'ncbi_protein_id:XP_027466234', 'uniprot_id:A0A6J2EBK8']
# mlx:118014356
# ['kegg:mlx', 'ncbi_gene_id:118014356', 'ncbi_protein_id:XP_034866467']
# nsu:110574111
# ['kegg:nsu', 'ncbi_gene_id:110574111', 'ncbi_protein_id:XP_021538443', 'uniprot_id:A0A2Y9GH54']
# lww:102747244
# ['kegg:lww', 'ncbi_gene_id:102747244', 'ncbi_protein_id:XP_006729208', 'uniprot_id:A0A2U3XD02']
# fca:101093325
# ['kegg:fca', 'ncbi_gene_id:101093325', 'ncbi_protein_id:XP_003999327']
# pyu:121038044
# ['kegg:pyu', 'ncbi_gene_id:121038044', 'ncbi_protein_id:XP_040343419']
# pyu:121011810
# ['kegg:pyu', 'ncbi_gene_id:121011810', 'ncbi_protein_id:XP_040302451']
# pcoo:112857852
# ['kegg:pcoo', 'ncbi_gene_id:112857852', 'ncbi_protein_id:XP_025776967', 'uniprot_id:A0A6P6HMJ2']
# pbg:122476285
# ['kegg:pbg', 'ncbi_gene_id:122476285', 'ncbi_protein_id:XP_043424720']
# pviv:125155188
# ['kegg:pviv', 'ncbi_gene_id:125155188', 'ncbi_protein_id:XP_047696128']
# lruf:124510140
# ['kegg:lruf', 'ncbi_gene_id:124510140', 'ncbi_protein_id:XP_046932820']
# ptg:102962409
# ['kegg:ptg', 'ncbi_gene_id:102962409', 'ncbi_protein_id:XP_007096265']
# ppad:109254106
# ['kegg:ppad', 'ncbi_gene_id:109254106', 'ncbi_protein_id:XP_019283285', 'uniprot_id:A0A9W2W2H1']
# puc:125924239
# ['kegg:puc', 'ncbi_gene_id:125924239', 'ncbi_protein_id:XP_049488641']
# puc:125925251
# ['kegg:puc', 'ncbi_gene_id:125925251', 'ncbi_protein_id:XP_049490085']
# aju:106966739
# ['kegg:aju', 'ncbi_gene_id:106966739', 'ncbi_protein_id:XP_026930204', 'uniprot_id:A0A6J2ANS6']
# hhv:120243229
# ['kegg:hhv', 'ncbi_gene_id:120243229', 'ncbi_protein_id:XP_039105243']
# bta:281199
# ['kegg:bta', 'ncbi_gene_id:281199', 'ncbi_protein_id:NP_001035564', 'uniprot_id:P15103']
# bom:102268791
# ['kegg:bom', 'ncbi_gene_id:102268791', 'ncbi_protein_id:XP_005910188']
# biu:109570357
# ['kegg:biu', 'ncbi_gene_id:109570357', 'ncbi_protein_id:XP_019831800', 'uniprot_id:A0A6P5D1Q0']
# bbub:102414633
# ['kegg:bbub', 'ncbi_gene_id:102414633', 'ncbi_protein_id:XP_006048672']
# bbis:104998093
# ['kegg:bbis', 'ncbi_gene_id:104998093', 'ncbi_protein_id:XP_010851424', 'uniprot_id:A0A6P3IHL8']
# chx:102191069
# ['kegg:chx', 'ncbi_gene_id:102191069', 'ncbi_protein_id:XP_017916175', 'uniprot_id:A0A452G2Q3']
# oas:101102999
# ['kegg:oas', 'ncbi_gene_id:101102999', 'ncbi_protein_id:XP_027831735']
# btax:128061599
# ['kegg:btax', 'ncbi_gene_id:128061599', 'ncbi_protein_id:XP_052509936']
# oda:120880488
# ['kegg:oda', 'ncbi_gene_id:120880488', 'ncbi_protein_id:XP_040119785']
# oda:120865484
# ['kegg:oda', 'ncbi_gene_id:120865484', 'ncbi_protein_id:XP_040098736']
# ccad:122434077
# ['kegg:ccad', 'ncbi_gene_id:122434077', 'ncbi_protein_id:XP_043313171']
# ccad:122452055
# ['kegg:ccad', 'ncbi_gene_id:122452055', 'ncbi_protein_id:XP_043341307']
# mbez:129551310
# ['kegg:mbez', 'ncbi_gene_id:129551310', 'ncbi_protein_id:XP_055275109']
# mbez:129559100
# ['kegg:mbez', 'ncbi_gene_id:129559100', 'ncbi_protein_id:XP_055286558']
# ssc:396944
# ['kegg:ssc', 'ncbi_gene_id:396944', 'ncbi_protein_id:NP_999074', 'uniprot_id:P46410']
# cfr:102511121
# ['kegg:cfr', 'ncbi_gene_id:102511121', 'ncbi_protein_id:XP_014421761', 'uniprot_id:A0A8B8RQK4']
# cfr:102516936
# ['kegg:cfr', 'ncbi_gene_id:102516936', 'ncbi_protein_id:XP_032350563', 'uniprot_id:A0A8B8U8E6']
# cbai:105068938
# ['kegg:cbai', 'ncbi_gene_id:105068938', 'ncbi_protein_id:XP_010953238', 'uniprot_id:A0A9W3EQ25']
# cdk:105096240
# ['kegg:cdk', 'ncbi_gene_id:105096240', 'ncbi_protein_id:XP_031291502']
# vpc:102541149
# ['kegg:vpc', 'ncbi_gene_id:102541149', 'ncbi_protein_id:XP_006211846', 'uniprot_id:A0A6I9IGJ6']
# bacu:103001460
# ['kegg:bacu', 'ncbi_gene_id:103001460', 'ncbi_protein_id:XP_007175243', 'uniprot_id:A0A383ZJB4']
# bmus:118900178
# ['kegg:bmus', 'ncbi_gene_id:118900178', 'ncbi_protein_id:XP_036718385', 'uniprot_id:A0A8B8YFX6']
# bmus:118896548
# ['kegg:bmus', 'ncbi_gene_id:118896548', 'ncbi_protein_id:XP_036710357', 'uniprot_id:A0A8B8XKP8']
# lve:103069050
# ['kegg:lve', 'ncbi_gene_id:103069050', 'ncbi_protein_id:XP_007448566', 'uniprot_id:A0A340WIL7']
# oor:101288727
# ['kegg:oor', 'ncbi_gene_id:101288727', 'ncbi_protein_id:XP_004269878']
# dle:111165660
# ['kegg:dle', 'ncbi_gene_id:111165660', 'ncbi_protein_id:XP_022412233', 'uniprot_id:A0A2Y9M4D2']
# pcad:102989047
# ['kegg:pcad', 'ncbi_gene_id:102989047', 'ncbi_protein_id:XP_007122734', 'uniprot_id:A0A2Y9FHB2']
# psiu:116752767
# ['kegg:psiu', 'ncbi_gene_id:116752767', 'ncbi_protein_id:XP_032485485']
# nasi:112408981
# ['kegg:nasi', 'ncbi_gene_id:112408981', 'ncbi_protein_id:XP_024614610', 'uniprot_id:A0A341CJG4']
# ecb:100054716
# ['kegg:ecb', 'ncbi_gene_id:100054716', 'ncbi_protein_id:XP_001489285']
# epz:103551859
# ['kegg:epz', 'ncbi_gene_id:103551859', 'ncbi_protein_id:XP_008519752']
# eai:106833909
# ['kegg:eai', 'ncbi_gene_id:106833909', 'ncbi_protein_id:XP_014700744']
# eai:106845663
# ['kegg:eai', 'ncbi_gene_id:106845663', 'ncbi_protein_id:XP_044626242']
# myb:102243515
# ['kegg:myb', 'ncbi_gene_id:102243515', 'ncbi_protein_id:XP_005880282']
# myd:102754853
# ['kegg:myd', 'ncbi_gene_id:102754853', 'ncbi_protein_id:XP_006754546']
# mmyo:118673167
# ['kegg:mmyo', 'ncbi_gene_id:118673167', 'ncbi_protein_id:XP_036199597']
# mlf:102434487
# ['kegg:mlf', 'ncbi_gene_id:102434487', 'ncbi_protein_id:XP_006089045']
# pkl:118721786
# ['kegg:pkl', 'ncbi_gene_id:118721786', 'ncbi_protein_id:XP_036298992']
# efus:103290007
# ['kegg:efus', 'ncbi_gene_id:103290007', 'ncbi_protein_id:XP_008144141']
# mna:107546301
# ['kegg:mna', 'ncbi_gene_id:107546301', 'ncbi_protein_id:XP_016080162']
# dro:112297973
# ['kegg:dro', 'ncbi_gene_id:112297973', 'ncbi_protein_id:XP_024408679']
# shon:118979141
# ['kegg:shon', 'ncbi_gene_id:118979141', 'ncbi_protein_id:XP_036891012']
# ajm:119039442
# ['kegg:ajm', 'ncbi_gene_id:119039442', 'ncbi_protein_id:XP_036988075']
# ajm:119049602
# ['kegg:ajm', 'ncbi_gene_id:119049602', 'ncbi_protein_id:XP_037001540']
# ajm:119049888
# ['kegg:ajm', 'ncbi_gene_id:119049888', 'ncbi_protein_id:XP_037001919']
# pdic:114511836
# ['kegg:pdic', 'ncbi_gene_id:114511836', 'ncbi_protein_id:XP_028386406', 'uniprot_id:A0A6J2N3F6']
# phas:123818566
# ['kegg:phas', 'ncbi_gene_id:123818566', 'ncbi_protein_id:XP_045694809']
# mmf:118637062
# ['kegg:mmf', 'ncbi_gene_id:118637062', 'ncbi_protein_id:XP_036128023']
# mmf:118632353
# ['kegg:mmf', 'ncbi_gene_id:118632353', 'ncbi_protein_id:XP_036121292']
# ppam:129081587
# ['kegg:ppam', 'ncbi_gene_id:129081587', 'ncbi_protein_id:XP_054443231']
# ppam:129081991
# ['kegg:ppam', 'ncbi_gene_id:129081991', 'ncbi_protein_id:XP_054443663']
# ppam:129064100
# ['kegg:ppam', 'ncbi_gene_id:129064100', 'ncbi_protein_id:XP_054421153']
# ppam:129067665
# ['kegg:ppam', 'ncbi_gene_id:129067665', 'ncbi_protein_id:XP_054425743']
# hai:109379162
# ['kegg:hai', 'ncbi_gene_id:109379162', 'ncbi_protein_id:XP_019491093', 'uniprot_id:A0A1U8WC65']
# rfq:117032407
# ['kegg:rfq', 'ncbi_gene_id:117032407', 'ncbi_protein_id:XP_032979825']
# rfq:117026955
# ['kegg:rfq', 'ncbi_gene_id:117026955', 'ncbi_protein_id:XP_032970165']
# rfq:117021215
# ['kegg:rfq', 'ncbi_gene_id:117021215', 'ncbi_protein_id:XP_032959930']
# rfq:117014438
# ['kegg:rfq', 'ncbi_gene_id:117014438', 'ncbi_protein_id:XP_032948211']
# pale:102894556
# ['kegg:pale', 'ncbi_gene_id:102894556', 'ncbi_protein_id:XP_006907826', 'uniprot_id:L5KXK5']
# pgig:120617588
# ['kegg:pgig', 'ncbi_gene_id:120617588', 'ncbi_protein_id:XP_039737241']
# pvp:105292831
# ['kegg:pvp', 'ncbi_gene_id:105292831', 'ncbi_protein_id:XP_011359508', 'uniprot_id:A0A6P3QA43']
# ray:107511281
# ['kegg:ray', 'ncbi_gene_id:107511281', 'ncbi_protein_id:XP_016001030']
# mjv:108405130
# ['kegg:mjv', 'ncbi_gene_id:108405130', 'ncbi_protein_id:XP_036876970']
# tod:119241208
# ['kegg:tod', 'ncbi_gene_id:119241208', 'ncbi_protein_id:XP_037362234']
# sara:101549482
# ['kegg:sara', 'ncbi_gene_id:101549482', 'ncbi_protein_id:XP_004613773']
# setr:126013439
# ['kegg:setr', 'ncbi_gene_id:126013439', 'ncbi_protein_id:XP_049632493']
# lav:100673871
# ['kegg:lav', 'ncbi_gene_id:100673871', 'ncbi_protein_id:XP_003410905', 'uniprot_id:G3SM75']
# tmu:101357360
# ['kegg:tmu', 'ncbi_gene_id:101357360', 'ncbi_protein_id:XP_023583865', 'uniprot_id:A0A2Y9QK86']
# etf:105978980
# ['kegg:etf', 'ncbi_gene_id:105978980', 'ncbi_protein_id:XP_045153877']
# dnm:101412851
# ['kegg:dnm', 'ncbi_gene_id:101412851', 'ncbi_protein_id:XP_004469184']
# mdo:100017907
# ['kegg:mdo', 'ncbi_gene_id:100017907', 'ncbi_protein_id:XP_007480978']
# gas:123247228
# ['kegg:gas', 'ncbi_gene_id:123247228', 'ncbi_protein_id:XP_044531976']
# gas:123235026
# ['kegg:gas', 'ncbi_gene_id:123235026', 'ncbi_protein_id:XP_044516987']
# shr:100930718
# ['kegg:shr', 'ncbi_gene_id:100930718', 'ncbi_protein_id:XP_031792854']
# afz:127562827
# ['kegg:afz', 'ncbi_gene_id:127562827', 'ncbi_protein_id:XP_051854784']
# pcw:110206833
# ['kegg:pcw', 'ncbi_gene_id:110206833', 'ncbi_protein_id:XP_020840017', 'uniprot_id:A0A6P5K4T4']
# oaa:100081935
# ['kegg:oaa', 'ncbi_gene_id:100081935', 'ncbi_protein_id:XP_001516345', 'uniprot_id:A0A6I8PF24']
# oaa:100093029
# ['kegg:oaa', 'ncbi_gene_id:100093029', 'ncbi_protein_id:XP_028910251']
# gga:396489
# ['kegg:gga', 'ncbi_gene_id:396489', 'ncbi_protein_id:NP_990824', 'uniprot_id:P16580']
# gga:417253
# ['kegg:gga', 'ncbi_gene_id:417253', 'ncbi_protein_id:XP_003642300', 'uniprot_id:F1P0D2']
# pcoc:116230460
# ['kegg:pcoc', 'ncbi_gene_id:116230460', 'ncbi_protein_id:XP_031451491']
# pcoc:116234160
# ['kegg:pcoc', 'ncbi_gene_id:116234160', 'ncbi_protein_id:XP_031457413']
# mgp:100539008
# ['kegg:mgp', 'ncbi_gene_id:100539008', 'ncbi_protein_id:XP_010719070']
# mgp:100545435
# ['kegg:mgp', 'ncbi_gene_id:100545435', 'ncbi_protein_id:XP_019474145']
# cjo:107317270
# ['kegg:cjo', 'ncbi_gene_id:107317270', 'ncbi_protein_id:XP_015725246', 'uniprot_id:A0A8C2UKH3']
# cjo:107321620
# ['kegg:cjo', 'ncbi_gene_id:107321620', 'ncbi_protein_id:XP_015734179']
# tpai:128072463
# ['kegg:tpai', 'ncbi_gene_id:128072463', 'ncbi_protein_id:XP_052522262']
# tpai:128073159
# ['kegg:tpai', 'ncbi_gene_id:128073159', 'ncbi_protein_id:XP_052523635']
# lmut:125702728
# ['kegg:lmut', 'ncbi_gene_id:125702728', 'ncbi_protein_id:XP_048822320']
# lmut:125693715
# ['kegg:lmut', 'ncbi_gene_id:125693715', 'ncbi_protein_id:XP_048801894']
# nmel:110402537
# ['kegg:nmel', 'ncbi_gene_id:110402537', 'ncbi_protein_id:XP_021260404']
# nmel:110406932
# ['kegg:nmel', 'ncbi_gene_id:110406932', 'ncbi_protein_id:XP_021269727']
# apla:101794703
# ['kegg:apla', 'ncbi_gene_id:101794703', 'ncbi_protein_id:XP_027326686']
# apla:101799450
# ['kegg:apla', 'ncbi_gene_id:101799450', 'ncbi_protein_id:XP_027318186']
# acyg:106047794
# ['kegg:acyg', 'ncbi_gene_id:106047794', 'ncbi_protein_id:XP_013054906']
# acyg:106037044
# ['kegg:acyg', 'ncbi_gene_id:106037044', 'ncbi_protein_id:XP_047906681']
# cata:118243277
# ['kegg:cata', 'ncbi_gene_id:118243277', 'ncbi_protein_id:XP_035393069']
# cata:118257087
# ['kegg:cata', 'ncbi_gene_id:118257087', 'ncbi_protein_id:XP_035420575']
# aful:116492108
# ['kegg:aful', 'ncbi_gene_id:116492108', 'ncbi_protein_id:XP_032048464', 'uniprot_id:A0A6J3DD65']
# aful:116496921
# ['kegg:aful', 'ncbi_gene_id:116496921', 'ncbi_protein_id:XP_032056237', 'uniprot_id:A0A6J3E2Z0']
# tgu:100229445
# ['kegg:tgu', 'ncbi_gene_id:100229445', 'ncbi_protein_id:XP_002196326']
# tgu:115490557
# ['kegg:tgu', 'ncbi_gene_id:115490557', 'ncbi_protein_id:XP_030142590']
# lsr:110479016
# ['kegg:lsr', 'ncbi_gene_id:110479016', 'ncbi_protein_id:XP_021401710']
# lsr:110476953
# ['kegg:lsr', 'ncbi_gene_id:110476953', 'ncbi_protein_id:XP_021397934']
# scan:103819060
# ['kegg:scan', 'ncbi_gene_id:103819060', 'ncbi_protein_id:XP_009091763', 'uniprot_id:A0A8C9UDG2']
# scan:103823365
# ['kegg:scan', 'ncbi_gene_id:103823365', 'ncbi_protein_id:XP_030082364']
# pmoa:120512244
# ['kegg:pmoa', 'ncbi_gene_id:120512244', 'ncbi_protein_id:XP_039586247']
# pmoa:120507514
# ['kegg:pmoa', 'ncbi_gene_id:120507514', 'ncbi_protein_id:XP_039576243']
# otc:121337125
# ['kegg:otc', 'ncbi_gene_id:121337125', 'ncbi_protein_id:XP_041262920']
# otc:121344233
# ['kegg:otc', 'ncbi_gene_id:121344233', 'ncbi_protein_id:XP_041275937']
# pruf:121359748
# ['kegg:pruf', 'ncbi_gene_id:121359748', 'ncbi_protein_id:XP_041334851']
# pruf:121357653
# ['kegg:pruf', 'ncbi_gene_id:121357653', 'ncbi_protein_id:XP_041331104']
# gfr:102042972
# ['kegg:gfr', 'ncbi_gene_id:102042972', 'ncbi_protein_id:XP_014163607']
# gfr:102040474
# ['kegg:gfr', 'ncbi_gene_id:102040474', 'ncbi_protein_id:XP_005431121']
# fab:101808562
# ['kegg:fab', 'ncbi_gene_id:101808562', 'ncbi_protein_id:XP_005055482', 'uniprot_id:A0A803V7G0']
# fab:101812640
# ['kegg:fab', 'ncbi_gene_id:101812640', 'ncbi_protein_id:XP_005049877', 'uniprot_id:U3JZZ9']
# oma:130260138
# ['kegg:oma', 'ncbi_gene_id:130260138', 'ncbi_protein_id:XP_056361252']
# oma:130256511
# ['kegg:oma', 'ncbi_gene_id:130256511', 'ncbi_protein_id:XP_056354207']
# phi:102099167
# ['kegg:phi', 'ncbi_gene_id:102099167', 'ncbi_protein_id:XP_005527241']
# phi:102100739
# ['kegg:phi', 'ncbi_gene_id:102100739', 'ncbi_protein_id:XP_005528747']
# pmaj:107208386
# ['kegg:pmaj', 'ncbi_gene_id:107208386', 'ncbi_protein_id:XP_015492237']
# pmaj:107211905
# ['kegg:pmaj', 'ncbi_gene_id:107211905', 'ncbi_protein_id:XP_015499978']
# ccae:111932625
# ['kegg:ccae', 'ncbi_gene_id:111932625', 'ncbi_protein_id:XP_023787536']
# ccae:111936925
# ['kegg:ccae', 'ncbi_gene_id:111936925', 'ncbi_protein_id:XP_023793841']
# ccw:104688229
# ['kegg:ccw', 'ncbi_gene_id:104688229', 'ncbi_protein_id:XP_010395911']
# ccw:104695478
# ['kegg:ccw', 'ncbi_gene_id:104695478', 'ncbi_protein_id:XP_039411838']
# cbrc:103612510
# ['kegg:cbrc', 'ncbi_gene_id:103612510', 'ncbi_protein_id:XP_017585105', 'uniprot_id:A0A091EH44']
# cbrc:103619753
# ['kegg:cbrc', 'ncbi_gene_id:103619753', 'ncbi_protein_id:XP_008636540']
# etl:114063530
# ['kegg:etl', 'ncbi_gene_id:114063530', 'ncbi_protein_id:XP_027751650']
# etl:114067148
# ['kegg:etl', 'ncbi_gene_id:114067148', 'ncbi_protein_id:XP_027758211']
# zab:102068766
# ['kegg:zab', 'ncbi_gene_id:102068766', 'ncbi_protein_id:XP_014125933']
# zab:102072733
# ['kegg:zab', 'ncbi_gene_id:102072733', 'ncbi_protein_id:XP_005492300', 'uniprot_id:A0A8D2MCX1']
# zle:135450798
# ['kegg:zle', 'ncbi_gene_id:135450798', 'ncbi_protein_id:XP_064575355']
# zle:135455090
# ['kegg:zle', 'ncbi_gene_id:135455090', 'ncbi_protein_id:XP_064584012']
# achl:103800879
# ['kegg:achl', 'ncbi_gene_id:103800879', 'ncbi_protein_id:XP_009071518', 'uniprot_id:A0A091MPG8']
# achl:103801726
# ['kegg:achl', 'ncbi_gene_id:103801726', 'ncbi_protein_id:XP_009072398']
# svg:106852282
# ['kegg:svg', 'ncbi_gene_id:106852282', 'ncbi_protein_id:XP_014730280']
# svg:106855972
# ['kegg:svg', 'ncbi_gene_id:106855972', 'ncbi_protein_id:XP_014736503']
# mmea:130580691
# ['kegg:mmea', 'ncbi_gene_id:130580691', 'ncbi_protein_id:XP_057234328']
# mmea:130583581
# ['kegg:mmea', 'ncbi_gene_id:130583581', 'ncbi_protein_id:XP_057239015']
# hrt:120761866
# ['kegg:hrt', 'ncbi_gene_id:120761866', 'ncbi_protein_id:XP_039939535']
# hrt:120756724
# ['kegg:hrt', 'ncbi_gene_id:120756724', 'ncbi_protein_id:XP_039929260']
# fpg:101915892
# ['kegg:fpg', 'ncbi_gene_id:101915892', 'ncbi_protein_id:XP_005231328']
# fpg:101918720
# ['kegg:fpg', 'ncbi_gene_id:101918720', 'ncbi_protein_id:XP_013150049']
# fch:102057417
# ['kegg:fch', 'ncbi_gene_id:102057417', 'ncbi_protein_id:XP_005442057']
# fch:102059225
# ['kegg:fch', 'ncbi_gene_id:102059225', 'ncbi_protein_id:XP_027656424']
# clv:102084334
# ['kegg:clv', 'ncbi_gene_id:102084334', 'ncbi_protein_id:XP_005501161', 'uniprot_id:A0A2I0MBT3']
# clv:102086143
# ['kegg:clv', 'ncbi_gene_id:102086143', 'ncbi_protein_id:XP_013226980', 'uniprot_id:A0A2I0LSZ6']
# egz:104124044
# ['kegg:egz', 'ncbi_gene_id:104124044', 'ncbi_protein_id:XP_009634643']
# egz:104132047
# ['kegg:egz', 'ncbi_gene_id:104132047', 'ncbi_protein_id:XP_009643586']
# nni:104022229
# ['kegg:nni', 'ncbi_gene_id:104022229', 'ncbi_protein_id:XP_009474191']
# nni:104010376
# ['kegg:nni', 'ncbi_gene_id:104010376', 'ncbi_protein_id:XP_009460760']
# pcri:104035046
# ['kegg:pcri', 'ncbi_gene_id:104035046', 'ncbi_protein_id:XP_009486485', 'uniprot_id:A0A091SYS3']
# pcri:104032129
# ['kegg:pcri', 'ncbi_gene_id:104032129', 'ncbi_protein_id:XP_009482646']
# plet:104614660
# ['kegg:plet', 'ncbi_gene_id:104614660', 'ncbi_protein_id:XP_010288449']
# plet:104624570
# ['kegg:plet', 'ncbi_gene_id:104624570', 'ncbi_protein_id:XP_010290273', 'uniprot_id:A0A091TRV6']
# ehs:104505630
# ['kegg:ehs', 'ncbi_gene_id:104505630', 'ncbi_protein_id:XP_010153803']
# ehs:104512049
# ['kegg:ehs', 'ncbi_gene_id:104512049', 'ncbi_protein_id:XP_010153186', 'uniprot_id:A0A093IGV2']
# pcao:104042711
# ['kegg:pcao', 'ncbi_gene_id:104042711', 'ncbi_protein_id:XP_009500499']
# pcao:104044778
# ['kegg:pcao', 'ncbi_gene_id:104044778', 'ncbi_protein_id:XP_009502950', 'uniprot_id:A0A093T8X1']
# acun:113482620
# ['kegg:acun', 'ncbi_gene_id:113482620', 'ncbi_protein_id:XP_026709221']
# acun:113486644
# ['kegg:acun', 'ncbi_gene_id:113486644', 'ncbi_protein_id:XP_026716521']
# tala:116963438
# ['kegg:tala', 'ncbi_gene_id:116963438', 'ncbi_protein_id:XP_032856046']
# tala:104362547
# ['kegg:tala', 'ncbi_gene_id:104362547', 'ncbi_protein_id:XP_042663617']
# padl:103914023
# ['kegg:padl', 'ncbi_gene_id:103914023', 'ncbi_protein_id:XP_009318909']
# padl:103918931
# ['kegg:padl', 'ncbi_gene_id:103918931', 'ncbi_protein_id:XP_009324631']
# afor:103896109
# ['kegg:afor', 'ncbi_gene_id:103896109', 'ncbi_protein_id:XP_009274158']
# afor:103901382
# ['kegg:afor', 'ncbi_gene_id:103901382', 'ncbi_protein_id:XP_019328393']
# achc:115335342
# ['kegg:achc', 'ncbi_gene_id:115335342', 'ncbi_protein_id:XP_029856707']
# achc:115348754
# ['kegg:achc', 'ncbi_gene_id:115348754', 'ncbi_protein_id:XP_029887787']
# hald:104313023
# ['kegg:hald', 'ncbi_gene_id:104313023', 'ncbi_protein_id:XP_009910083', 'uniprot_id:A0A091NXX6']
# hald:104314163
# ['kegg:hald', 'ncbi_gene_id:104314163', 'ncbi_protein_id:XP_009911810']
# hle:104833973
# ['kegg:hle', 'ncbi_gene_id:104833973', 'ncbi_protein_id:XP_010569338']
# hle:104839978
# ['kegg:hle', 'ncbi_gene_id:104839978', 'ncbi_protein_id:XP_010578922']
# agen:126041550
# ['kegg:agen', 'ncbi_gene_id:126041550', 'ncbi_protein_id:XP_049663354']
# agen:126052322
# ['kegg:agen', 'ncbi_gene_id:126052322', 'ncbi_protein_id:XP_049688816']
# gcl:127018901
# ['kegg:gcl', 'ncbi_gene_id:127018901', 'ncbi_protein_id:XP_050756657']
# gcl:127023650
# ['kegg:gcl', 'ncbi_gene_id:127023650', 'ncbi_protein_id:XP_050763834']
# ccri:104155434
# ['kegg:ccri', 'ncbi_gene_id:104155434', 'ncbi_protein_id:XP_009699257']
# ccri:104159249
# ['kegg:ccri', 'ncbi_gene_id:104159249', 'ncbi_protein_id:XP_009695406']
# csti:104558466
# ['kegg:csti', 'ncbi_gene_id:104558466', 'ncbi_protein_id:XP_010201361', 'uniprot_id:A0A091K413']
# csti:104549786
# ['kegg:csti', 'ncbi_gene_id:104549786', 'ncbi_protein_id:XP_010195584']
# cmac:104479947
# ['kegg:cmac', 'ncbi_gene_id:104479947', 'ncbi_protein_id:XP_010119026', 'uniprot_id:A0A091KRI3']
# cmac:104480411
# ['kegg:cmac', 'ncbi_gene_id:104480411', 'ncbi_protein_id:XP_010119641']
# mui:104539967
# ['kegg:mui', 'ncbi_gene_id:104539967', 'ncbi_protein_id:XP_010181950']
# mui:104546094
# ['kegg:mui', 'ncbi_gene_id:104546094', 'ncbi_protein_id:XP_010189689']
# breg:104631947
# ['kegg:breg', 'ncbi_gene_id:104631947', 'ncbi_protein_id:XP_010295961']
# breg:104643553
# ['kegg:breg', 'ncbi_gene_id:104643553', 'ncbi_protein_id:XP_010311207', 'uniprot_id:A0A087V636']
# fga:104076604
# ['kegg:fga', 'ncbi_gene_id:104076604', 'ncbi_protein_id:XP_009575817']
# fga:104075716
# ['kegg:fga', 'ncbi_gene_id:104075716', 'ncbi_protein_id:XP_009574605', 'uniprot_id:A0A093ILN4']
# gste:104262736
# ['kegg:gste', 'ncbi_gene_id:104262736', 'ncbi_protein_id:XP_009817483']
# gste:104261191
# ['kegg:gste', 'ncbi_gene_id:104261191', 'ncbi_protein_id:XP_009815436']
# ldi:104340818
# ['kegg:ldi', 'ncbi_gene_id:104340818', 'ncbi_protein_id:XP_009944340']
# ldi:104350500
# ['kegg:ldi', 'ncbi_gene_id:104350500', 'ncbi_protein_id:XP_009954654', 'uniprot_id:A0A091Q506']
# mnb:103779292
# ['kegg:mnb', 'ncbi_gene_id:103779292', 'ncbi_protein_id:XP_008945167', 'uniprot_id:A0A091RAL5']
# mnb:103781443
# ['kegg:mnb', 'ncbi_gene_id:103781443', 'ncbi_protein_id:XP_008947411']
# oha:104333705
# ['kegg:oha', 'ncbi_gene_id:104333705', 'ncbi_protein_id:XP_009937541']
# oha:104335648
# ['kegg:oha', 'ncbi_gene_id:104335648', 'ncbi_protein_id:XP_009939700']
# nnt:104413085
# ['kegg:nnt', 'ncbi_gene_id:104413085', 'ncbi_protein_id:XP_010022299']
# nnt:104406935
# ['kegg:nnt', 'ncbi_gene_id:104406935', 'ncbi_protein_id:XP_010014362', 'uniprot_id:A0A091S3K1']
# shab:115617083
# ['kegg:shab', 'ncbi_gene_id:115617083', 'ncbi_protein_id:XP_030363041']
# shab:115611876
# ['kegg:shab', 'ncbi_gene_id:115611876', 'ncbi_protein_id:XP_030351346']
# dpub:104301531
# ['kegg:dpub', 'ncbi_gene_id:104301531', 'ncbi_protein_id:XP_009900219']
# dpub:104296982
# ['kegg:dpub', 'ncbi_gene_id:104296982', 'ncbi_protein_id:XP_009895151']
# pguu:104462401
# ['kegg:pguu', 'ncbi_gene_id:104462401', 'ncbi_protein_id:XP_010072625', 'uniprot_id:A0A093C3L5']
# pguu:104461586
# ['kegg:pguu', 'ncbi_gene_id:104461586', 'ncbi_protein_id:XP_010071525']
# acar:104524654
# ['kegg:acar', 'ncbi_gene_id:104524654', 'ncbi_protein_id:XP_010165903', 'uniprot_id:A0A094MTK1']
# acar:104517713
# ['kegg:acar', 'ncbi_gene_id:104517713', 'ncbi_protein_id:XP_010161214']
# cpea:104385848
# ['kegg:cpea', 'ncbi_gene_id:104385848', 'ncbi_protein_id:XP_009992649']
# cpea:104386094
# ['kegg:cpea', 'ncbi_gene_id:104386094', 'ncbi_protein_id:XP_009992929']
# avit:104276664
# ['kegg:avit', 'ncbi_gene_id:104276664', 'ncbi_protein_id:XP_009871372']
# avit:104277046
# ['kegg:avit', 'ncbi_gene_id:104277046', 'ncbi_protein_id:XP_009871871']
# cvf:104293339
# ['kegg:cvf', 'ncbi_gene_id:104293339', 'ncbi_protein_id:XP_009891139']
# cvf:104289065
# ['kegg:cvf', 'ncbi_gene_id:104289065', 'ncbi_protein_id:XP_009886262']
# rtd:128913780
# ['kegg:rtd', 'ncbi_gene_id:128913780', 'ncbi_protein_id:XP_054067931']
# rtd:128917699
# ['kegg:rtd', 'ncbi_gene_id:128917699', 'ncbi_protein_id:XP_054077066']
# cuca:104055876
# ['kegg:cuca', 'ncbi_gene_id:104055876', 'ncbi_protein_id:XP_009555358']
# cuca:104058145
# ['kegg:cuca', 'ncbi_gene_id:104058145', 'ncbi_protein_id:XP_009557906']
# teo:104383387
# ['kegg:teo', 'ncbi_gene_id:104383387', 'ncbi_protein_id:XP_009989837', 'uniprot_id:A0A093BZ73']
# teo:104383655
# ['kegg:teo', 'ncbi_gene_id:104383655', 'ncbi_protein_id:XP_009990166']
# brhi:104501345
# ['kegg:brhi', 'ncbi_gene_id:104501345', 'ncbi_protein_id:XP_010143447']
# brhi:104499072
# ['kegg:brhi', 'ncbi_gene_id:104499072', 'ncbi_protein_id:XP_010140834', 'uniprot_id:A0A091HFX8']
# aam:106494096
# ['kegg:aam', 'ncbi_gene_id:106494096', 'ncbi_protein_id:XP_013809735', 'uniprot_id:A0A8B7JF88']
# aam:106493025
# ['kegg:aam', 'ncbi_gene_id:106493025', 'ncbi_protein_id:XP_013808436', 'uniprot_id:A0A8B7JBK2']
# aam:106493043
# ['kegg:aam', 'ncbi_gene_id:106493043', 'ncbi_protein_id:XP_013808455', 'uniprot_id:A0A8B7JBK3']
# arow:112963043
# ['kegg:arow', 'ncbi_gene_id:112963043', 'ncbi_protein_id:XP_025915539']
# arow:112975076
# ['kegg:arow', 'ncbi_gene_id:112975076', 'ncbi_protein_id:XP_025940516']
# npd:112955888
# ['kegg:npd', 'ncbi_gene_id:112955888', 'ncbi_protein_id:XP_025905130']
# npd:112950399
# ['kegg:npd', 'ncbi_gene_id:112950399', 'ncbi_protein_id:XP_025898708']
# tgt:104581056
# ['kegg:tgt', 'ncbi_gene_id:104581056', 'ncbi_protein_id:XP_010226911', 'uniprot_id:A0A099Z0C2']
# tgt:104568594
# ['kegg:tgt', 'ncbi_gene_id:104568594', 'ncbi_protein_id:XP_010213799']
# dne:112983747
# ['kegg:dne', 'ncbi_gene_id:112983747', 'ncbi_protein_id:XP_025956859']
# dne:112991326
# ['kegg:dne', 'ncbi_gene_id:112991326', 'ncbi_protein_id:XP_025969528']
# scam:104139777
# ['kegg:scam', 'ncbi_gene_id:104139777', 'ncbi_protein_id:XP_009666435']
# scam:104142667
# ['kegg:scam', 'ncbi_gene_id:104142667', 'ncbi_protein_id:XP_009671042', 'uniprot_id:A0A093JMX8']
# asn:102387690
# ['kegg:asn', 'ncbi_gene_id:102387690', 'ncbi_protein_id:XP_006025447', 'uniprot_id:A0A1U7RX53']
# asn:102376806
# ['kegg:asn', 'ncbi_gene_id:102376806', 'ncbi_protein_id:XP_014378238', 'uniprot_id:A0A1U7S5V2']
# amj:102566561
# ['kegg:amj', 'ncbi_gene_id:102566561', 'ncbi_protein_id:XP_006273922', 'uniprot_id:A0A151MF36']
# amj:102562433
# ['kegg:amj', 'ncbi_gene_id:102562433', 'ncbi_protein_id:XP_014451506', 'uniprot_id:A0A151MI87']
# cpoo:109313836
# ['kegg:cpoo', 'ncbi_gene_id:109313836', 'ncbi_protein_id:XP_019396139', 'uniprot_id:A0A7M4F311']
# cpoo:109307189
# ['kegg:cpoo', 'ncbi_gene_id:109307189', 'ncbi_protein_id:XP_019386500', 'uniprot_id:A0A7M4F549']
# ggn:109286942
# ['kegg:ggn', 'ncbi_gene_id:109286942', 'ncbi_protein_id:XP_019357306']
# ggn:109292860
# ['kegg:ggn', 'ncbi_gene_id:109292860', 'ncbi_protein_id:XP_019366013']
# pss:102449981
# ['kegg:pss', 'ncbi_gene_id:102449981', 'ncbi_protein_id:XP_006137221']
# pss:102443909
# ['kegg:pss', 'ncbi_gene_id:102443909', 'ncbi_protein_id:XP_006126993', 'uniprot_id:K7FMU7']
# cmy:102945184
# ['kegg:cmy', 'ncbi_gene_id:102945184', 'ncbi_protein_id:XP_007061207']
# cmy:102933212
# ['kegg:cmy', 'ncbi_gene_id:102933212', 'ncbi_protein_id:XP_037735733']
# ccay:125640908
# ['kegg:ccay', 'ncbi_gene_id:125640908', 'ncbi_protein_id:XP_048715981']
# ccay:125623558
# ['kegg:ccay', 'ncbi_gene_id:125623558', 'ncbi_protein_id:XP_048679089']
# dcc:119860438
# ['kegg:dcc', 'ncbi_gene_id:119860438', 'ncbi_protein_id:XP_038270085']
# dcc:119844311
# ['kegg:dcc', 'ncbi_gene_id:119844311', 'ncbi_protein_id:XP_038230902']
# cpic:101939162
# ['kegg:cpic', 'ncbi_gene_id:101939162', 'ncbi_protein_id:XP_005290809', 'uniprot_id:A0A8C3HQV6']
# cpic:101945891
# ['kegg:cpic', 'ncbi_gene_id:101945891', 'ncbi_protein_id:XP_005309191', 'uniprot_id:A0A8C3II95']
# tst:117881709
# ['kegg:tst', 'ncbi_gene_id:117881709', 'ncbi_protein_id:XP_034635185']
# tst:117889564
# ['kegg:tst', 'ncbi_gene_id:117889564', 'ncbi_protein_id:XP_034649844']
# cabi:116818485
# ['kegg:cabi', 'ncbi_gene_id:116818485', 'ncbi_protein_id:XP_032625306']
# cabi:116816180
# ['kegg:cabi', 'ncbi_gene_id:116816180', 'ncbi_protein_id:XP_032621107']
# mrv:120370624
# ['kegg:mrv', 'ncbi_gene_id:120370624', 'ncbi_protein_id:XP_039341584']
# mrv:120386907
# ['kegg:mrv', 'ncbi_gene_id:120386907', 'ncbi_protein_id:XP_039362851']
# mrv:120381821
# ['kegg:mrv', 'ncbi_gene_id:120381821', 'ncbi_protein_id:XP_039355909']
# acs:100559692
# ['kegg:acs', 'ncbi_gene_id:100559692', 'ncbi_protein_id:XP_003228389']
# acs:100561986
# ['kegg:acs', 'ncbi_gene_id:100561986', 'ncbi_protein_id:XP_003228795']
# asao:132774391
# ['kegg:asao', 'ncbi_gene_id:132774391', 'ncbi_protein_id:XP_060630449']
# asao:132763664
# ['kegg:asao', 'ncbi_gene_id:132763664', 'ncbi_protein_id:XP_060613323']
# pvt:110077057
# ['kegg:pvt', 'ncbi_gene_id:110077057', 'ncbi_protein_id:XP_020645398', 'uniprot_id:A0A6J0TCX9']
# pvt:110087437
# ['kegg:pvt', 'ncbi_gene_id:110087437', 'ncbi_protein_id:XP_020664782', 'uniprot_id:A0A6J0UVP6']
# sund:121927739
# ['kegg:sund', 'ncbi_gene_id:121927739', 'ncbi_protein_id:XP_042317532']
# sund:121936456
# ['kegg:sund', 'ncbi_gene_id:121936456', 'ncbi_protein_id:XP_042334650']
# pbi:103058433
# ['kegg:pbi', 'ncbi_gene_id:103058433', 'ncbi_protein_id:XP_007421527', 'uniprot_id:A0A9F2N9P4']
# pbi:103052634
# ['kegg:pbi', 'ncbi_gene_id:103052634', 'ncbi_protein_id:XP_007441097', 'uniprot_id:A0A9F2WK86']
# pmur:107300203
# ['kegg:pmur', 'ncbi_gene_id:107300203', 'ncbi_protein_id:XP_015685027']
# pmur:107284992
# ['kegg:pmur', 'ncbi_gene_id:107284992', 'ncbi_protein_id:XP_015668617']
# ctig:120305373
# ['kegg:ctig', 'ncbi_gene_id:120305373', 'ncbi_protein_id:XP_039193054']
# ctig:120300738
# ['kegg:ctig', 'ncbi_gene_id:120300738', 'ncbi_protein_id:XP_039183064']
# tsr:106556132
# ['kegg:tsr', 'ncbi_gene_id:106556132', 'ncbi_protein_id:XP_013930581', 'uniprot_id:A0A6I9Z3N5']
# tsr:106547127
# ['kegg:tsr', 'ncbi_gene_id:106547127', 'ncbi_protein_id:XP_013919658', 'uniprot_id:A0A6I9Y5B1']
# pgut:117661133
# ['kegg:pgut', 'ncbi_gene_id:117661133', 'ncbi_protein_id:XP_034265557', 'uniprot_id:A0A6P9B2W3']
# pgut:117670269
# ['kegg:pgut', 'ncbi_gene_id:117670269', 'ncbi_protein_id:XP_034281207', 'uniprot_id:A0A6P9CD09']
# apri:131196228
# ['kegg:apri', 'ncbi_gene_id:131196228', 'ncbi_protein_id:XP_058034744']
# apri:131186159
# ['kegg:apri', 'ncbi_gene_id:131186159', 'ncbi_protein_id:XP_058015459']
# ptex:113438078
# ['kegg:ptex', 'ncbi_gene_id:113438078', 'ncbi_protein_id:XP_026559074']
# ptex:113443951
# ['kegg:ptex', 'ncbi_gene_id:113443951', 'ncbi_protein_id:XP_026568262']
# nss:113424797
# ['kegg:nss', 'ncbi_gene_id:113424797', 'ncbi_protein_id:XP_026542445', 'uniprot_id:A0A6J1VHQ9']
# nss:113413168
# ['kegg:nss', 'ncbi_gene_id:113413168', 'ncbi_protein_id:XP_026525026', 'uniprot_id:A0A6J1U2P2']
# vko:123027892
# ['kegg:vko', 'ncbi_gene_id:123027892', 'ncbi_protein_id:XP_044295137']
# vko:123028315
# ['kegg:vko', 'ncbi_gene_id:123028315', 'ncbi_protein_id:XP_044295956']
# pmua:114598515
# ['kegg:pmua', 'ncbi_gene_id:114598515', 'ncbi_protein_id:XP_028588088']
# pmua:114589060
# ['kegg:pmua', 'ncbi_gene_id:114589060', 'ncbi_protein_id:XP_028570889']
# praf:128406492
# ['kegg:praf', 'ncbi_gene_id:128406492', 'ncbi_protein_id:XP_053229893']
# praf:128415208
# ['kegg:praf', 'ncbi_gene_id:128415208', 'ncbi_protein_id:XP_053247118']
# zvi:118088360
# ['kegg:zvi', 'ncbi_gene_id:118088360', 'ncbi_protein_id:XP_034977837']
# zvi:118084393
# ['kegg:zvi', 'ncbi_gene_id:118084393', 'ncbi_protein_id:XP_034969764']
# hcg:128325190
# ['kegg:hcg', 'ncbi_gene_id:128325190', 'ncbi_protein_id:XP_053106690']
# hcg:128338759
# ['kegg:hcg', 'ncbi_gene_id:128338759', 'ncbi_protein_id:XP_053137604']
# gja:107113657
# ['kegg:gja', 'ncbi_gene_id:107113657', 'ncbi_protein_id:XP_015270493']
# gja:107118791
# ['kegg:gja', 'ncbi_gene_id:107118791', 'ncbi_protein_id:XP_015276645']
# stow:125441884
# ['kegg:stow', 'ncbi_gene_id:125441884', 'ncbi_protein_id:XP_048368818']
# stow:125432356
# ['kegg:stow', 'ncbi_gene_id:125432356', 'ncbi_protein_id:XP_048351761']
# emc:129329988
# ['kegg:emc', 'ncbi_gene_id:129329988', 'ncbi_protein_id:XP_054835764', 'uniprot_id:A0AA97JES7']
# emc:129342658
# ['kegg:emc', 'ncbi_gene_id:129342658', 'ncbi_protein_id:XP_054854507', 'uniprot_id:A0AA97LJX1']
# xla:398556
# ['kegg:xla', 'ncbi_gene_id:398556', 'ncbi_protein_id:NP_001082548', 'uniprot_id:P51121']
# xla:432308
# ['kegg:xla', 'ncbi_gene_id:432308', 'ncbi_protein_id:NP_001085214', 'uniprot_id:Q6INY0']
# xla:380593
# ['kegg:xla', 'ncbi_gene_id:380593', 'ncbi_protein_id:NP_001080899', 'uniprot_id:Q7SZ38']
# xla:444294
# ['kegg:xla', 'ncbi_gene_id:444294', 'ncbi_protein_id:NP_001085867', 'uniprot_id:Q7M567']
# xla:108700639
# ['kegg:xla', 'ncbi_gene_id:108700639', 'ncbi_protein_id:XP_041431010', 'uniprot_id:A0A8J1LQK8']
# xtr:394904
# ['kegg:xtr', 'ncbi_gene_id:394904', 'ncbi_protein_id:NP_001363841', 'uniprot_id:F6VAG8']
# xtr:100498257
# ['kegg:xtr', 'ncbi_gene_id:100498257', 'ncbi_protein_id:XP_031747972', 'uniprot_id:A0A6I8RNU2']
# xtr:394915
# ['kegg:xtr', 'ncbi_gene_id:394915', 'ncbi_protein_id:NP_989297', 'uniprot_id:Q6P348']
# npr:108792571
# ['kegg:npr', 'ncbi_gene_id:108792571', 'ncbi_protein_id:XP_018418877']
# npr:108794381
# ['kegg:npr', 'ncbi_gene_id:108794381', 'ncbi_protein_id:XP_018420911']
# rtem:120945816
# ['kegg:rtem', 'ncbi_gene_id:120945816', 'ncbi_protein_id:XP_040216184']
# rtem:120913878
# ['kegg:rtem', 'ncbi_gene_id:120913878', 'ncbi_protein_id:XP_040180125']
# bbuf:121009384
# ['kegg:bbuf', 'ncbi_gene_id:121009384', 'ncbi_protein_id:XP_040298405']
# bbuf:121009385
# ['kegg:bbuf', 'ncbi_gene_id:121009385', 'ncbi_protein_id:XP_040298407']
# bbuf:120978440
# ['kegg:bbuf', 'ncbi_gene_id:120978440', 'ncbi_protein_id:XP_040262490']
# bgar:122943095
# ['kegg:bgar', 'ncbi_gene_id:122943095', 'ncbi_protein_id:XP_044156469']
# bgar:122929651
# ['kegg:bgar', 'ncbi_gene_id:122929651', 'ncbi_protein_id:XP_044139219']
# bgar:122946342
# ['kegg:bgar', 'ncbi_gene_id:122946342', 'ncbi_protein_id:XP_044161837']
# muo:115472713
# ['kegg:muo', 'ncbi_gene_id:115472713', 'ncbi_protein_id:XP_030062936', 'uniprot_id:A0A6P7YDC3']
# muo:115473324
# ['kegg:muo', 'ncbi_gene_id:115473324', 'ncbi_protein_id:XP_030064044', 'uniprot_id:A0A6P7YLX4']
# muo:115473325
# ['kegg:muo', 'ncbi_gene_id:115473325', 'ncbi_protein_id:XP_030064045', 'uniprot_id:A0A6P7YLQ7']
# gsh:117346812
# ['kegg:gsh', 'ncbi_gene_id:117346812', 'ncbi_protein_id:XP_033772821', 'uniprot_id:A0A6P8PBB7']
# gsh:117346900
# ['kegg:gsh', 'ncbi_gene_id:117346900', 'ncbi_protein_id:XP_033773027', 'uniprot_id:A0A6P8NBC5']
# gsh:117368423
# ['kegg:gsh', 'ncbi_gene_id:117368423', 'ncbi_protein_id:XP_033817960', 'uniprot_id:A0A6P8SGE2']
# dre:100000775
# ['kegg:dre', 'ncbi_gene_id:100000775', 'ncbi_protein_id:NP_853537', 'uniprot_id:Q7T2P7']
# dre:336473
# ['kegg:dre', 'ncbi_gene_id:336473', 'ncbi_protein_id:NP_878286', 'uniprot_id:Q7ZVF2']
# dre:566165
# ['kegg:dre', 'ncbi_gene_id:566165', 'ncbi_protein_id:NP_001068582', 'uniprot_id:Q08CT3']
# srx:107710552
# ['kegg:srx', 'ncbi_gene_id:107710552', 'ncbi_protein_id:XP_016370835', 'uniprot_id:A0A673MYE7']
# srx:107732203
# ['kegg:srx', 'ncbi_gene_id:107732203', 'ncbi_protein_id:XP_016398969', 'uniprot_id:A0A673MFW3']
# srx:107757425
# ['kegg:srx', 'ncbi_gene_id:107757425', 'ncbi_protein_id:XP_016430381', 'uniprot_id:A0A673NFC6']
# srx:107739708
# ['kegg:srx', 'ncbi_gene_id:107739708', 'ncbi_protein_id:XP_016407399', 'uniprot_id:A0A673IX83']
# srx:107733907
# ['kegg:srx', 'ncbi_gene_id:107733907', 'ncbi_protein_id:XP_016401239', 'uniprot_id:A0A673L4H9']
# srx:107736929
# ['kegg:srx', 'ncbi_gene_id:107736929', 'ncbi_protein_id:XP_016403803']
# sanh:107660462
# ['kegg:sanh', 'ncbi_gene_id:107660462', 'ncbi_protein_id:XP_016305252', 'uniprot_id:A0A671SF04']
# sanh:107662860
# ['kegg:sanh', 'ncbi_gene_id:107662860', 'ncbi_protein_id:XP_016308461', 'uniprot_id:A0A671NTN6']
# sanh:107677515
# ['kegg:sanh', 'ncbi_gene_id:107677515', 'ncbi_protein_id:XP_016327933', 'uniprot_id:A0A671LL72']
# sanh:107677524
# ['kegg:sanh', 'ncbi_gene_id:107677524', 'ncbi_protein_id:XP_016327941']
# sanh:107692327
# ['kegg:sanh', 'ncbi_gene_id:107692327', 'ncbi_protein_id:XP_016346795', 'uniprot_id:A0A671QBT1']
# sanh:107700548
# ['kegg:sanh', 'ncbi_gene_id:107700548', 'ncbi_protein_id:XP_016357733', 'uniprot_id:A0A671RTS7']
# sanh:107704001
# ['kegg:sanh', 'ncbi_gene_id:107704001', 'ncbi_protein_id:XP_016362302']
# sgh:107595722
# ['kegg:sgh', 'ncbi_gene_id:107595722', 'ncbi_protein_id:XP_016141703', 'uniprot_id:A0A672N374']
# sgh:107548798
# ['kegg:sgh', 'ncbi_gene_id:107548798', 'ncbi_protein_id:XP_016085101', 'uniprot_id:A0A672SGR1']
# sgh:107548799
# ['kegg:sgh', 'ncbi_gene_id:107548799', 'ncbi_protein_id:XP_016085102']
# sgh:107555380
# ['kegg:sgh', 'ncbi_gene_id:107555380', 'ncbi_protein_id:XP_016093631', 'uniprot_id:A0A672JT62']
# sgh:107553252
# ['kegg:sgh', 'ncbi_gene_id:107553252', 'ncbi_protein_id:XP_016090907', 'uniprot_id:A0A672L730']
# sgh:107563291
# ['kegg:sgh', 'ncbi_gene_id:107563291', 'ncbi_protein_id:XP_016103597', 'uniprot_id:A0A672QEH0']
# sgh:107569358
# ['kegg:sgh', 'ncbi_gene_id:107569358', 'ncbi_protein_id:XP_016110925', 'uniprot_id:A0A672QKJ2']
# ccar:109056015
# ['kegg:ccar', 'ncbi_gene_id:109056015', 'ncbi_protein_id:XP_018928746']
# ccar:109046284
# ['kegg:ccar', 'ncbi_gene_id:109046284', 'ncbi_protein_id:XP_018919605']
# ccar:109106083
# ['kegg:ccar', 'ncbi_gene_id:109106083', 'ncbi_protein_id:XP_018974950', 'uniprot_id:A0A9Q9VHS1']
# ccar:109069865
# ['kegg:ccar', 'ncbi_gene_id:109069865', 'ncbi_protein_id:XP_018942008', 'uniprot_id:A0A8C2JHC3']
# ccar:109080911
# ['kegg:ccar', 'ncbi_gene_id:109080911', 'ncbi_protein_id:XP_018951462']
# ccar:109074426
# ['kegg:ccar', 'ncbi_gene_id:109074426', 'ncbi_protein_id:XP_018946005']
# caua:113115323
# ['kegg:caua', 'ncbi_gene_id:113115323', 'ncbi_protein_id:XP_026138601', 'uniprot_id:A0A6P6QZC0']
# caua:113050664
# ['kegg:caua', 'ncbi_gene_id:113050664', 'ncbi_protein_id:XP_026069659', 'uniprot_id:A0A6P6KBQ9']
# caua:113097736
# ['kegg:caua', 'ncbi_gene_id:113097736', 'ncbi_protein_id:XP_026118773', 'uniprot_id:A0A6P6PCG8']
# caua:113063734
# ['kegg:caua', 'ncbi_gene_id:113063734', 'ncbi_protein_id:XP_026089846', 'uniprot_id:A0A6P6M200']
# caua:113045628
# ['kegg:caua', 'ncbi_gene_id:113045628', 'ncbi_protein_id:XP_026061895', 'uniprot_id:A0A6P6JQK7']
# caua:113038790
# ['kegg:caua', 'ncbi_gene_id:113038790', 'ncbi_protein_id:XP_026052231', 'uniprot_id:A0A6P6IWY5']
# cgib:127942060
# ['kegg:cgib', 'ncbi_gene_id:127942060', 'ncbi_protein_id:XP_052393561']
# cgib:127959837
# ['kegg:cgib', 'ncbi_gene_id:127959837', 'ncbi_protein_id:XP_052415185']
# cgib:127951030
# ['kegg:cgib', 'ncbi_gene_id:127951030', 'ncbi_protein_id:XP_052404593']
# cgib:128015510
# ['kegg:cgib', 'ncbi_gene_id:128015510', 'ncbi_protein_id:XP_052455348']
# cgib:127986183
# ['kegg:cgib', 'ncbi_gene_id:127986183', 'ncbi_protein_id:XP_052444396']
# cgib:128026735
# ['kegg:cgib', 'ncbi_gene_id:128026735', 'ncbi_protein_id:XP_052469966']
# ptet:122324425
# ['kegg:ptet', 'ncbi_gene_id:122324425', 'ncbi_protein_id:XP_043074757']
# ptet:122326669
# ['kegg:ptet', 'ncbi_gene_id:122326669', 'ncbi_protein_id:XP_043077683']
# ptet:122347213
# ['kegg:ptet', 'ncbi_gene_id:122347213', 'ncbi_protein_id:XP_043098298']
# lroh:127166920
# ['kegg:lroh', 'ncbi_gene_id:127166920', 'ncbi_protein_id:XP_050968580']
# lroh:127179720
# ['kegg:lroh', 'ncbi_gene_id:127179720', 'ncbi_protein_id:XP_050989378']
# lroh:127152663
# ['kegg:lroh', 'ncbi_gene_id:127152663', 'ncbi_protein_id:XP_050949408']
# omc:131531313
# ['kegg:omc', 'ncbi_gene_id:131531313', 'ncbi_protein_id:XP_058617983']
# omc:131542070
# ['kegg:omc', 'ncbi_gene_id:131542070', 'ncbi_protein_id:XP_058634348']
# omc:131529190
# ['kegg:omc', 'ncbi_gene_id:131529190', 'ncbi_protein_id:XP_058614746']
# pprm:120482700
# ['kegg:pprm', 'ncbi_gene_id:120482700', 'ncbi_protein_id:XP_039533199']
# pprm:120490823
# ['kegg:pprm', 'ncbi_gene_id:120490823', 'ncbi_protein_id:XP_039544222']
# pprm:120493149
# ['kegg:pprm', 'ncbi_gene_id:120493149', 'ncbi_protein_id:XP_039547573']
# rkg:130094470
# ['kegg:rkg', 'ncbi_gene_id:130094470', 'ncbi_protein_id:XP_056116746']
# rkg:130078693
# ['kegg:rkg', 'ncbi_gene_id:130078693', 'ncbi_protein_id:XP_056100265']
# rkg:130078698
# ['kegg:rkg', 'ncbi_gene_id:130078698', 'ncbi_protein_id:XP_056100269']
# rkg:130081243
# ['kegg:rkg', 'ncbi_gene_id:130081243', 'ncbi_protein_id:XP_056102201']
# mamb:125253222
# ['kegg:mamb', 'ncbi_gene_id:125253222', 'ncbi_protein_id:XP_048023045']
# mamb:125253223
# ['kegg:mamb', 'ncbi_gene_id:125253223', 'ncbi_protein_id:XP_048023046']
# mamb:125273848
# ['kegg:mamb', 'ncbi_gene_id:125273848', 'ncbi_protein_id:XP_048055530']
# mamb:125250860
# ['kegg:mamb', 'ncbi_gene_id:125250860', 'ncbi_protein_id:XP_048019607']
# cide:127514534
# ['kegg:cide', 'ncbi_gene_id:127514534', 'ncbi_protein_id:XP_051753415']
# cide:127499809
# ['kegg:cide', 'ncbi_gene_id:127499809', 'ncbi_protein_id:XP_051726378']
# cide:127504324
# ['kegg:cide', 'ncbi_gene_id:127504324', 'ncbi_protein_id:XP_051734833']
# masi:127430602
# ['kegg:masi', 'ncbi_gene_id:127430602', 'ncbi_protein_id:XP_051536444']
# masi:127446595
# ['kegg:masi', 'ncbi_gene_id:127446595', 'ncbi_protein_id:XP_051563602']
# masi:127428604
# ['kegg:masi', 'ncbi_gene_id:127428604', 'ncbi_protein_id:XP_051533004']
# masi:127428605
# ['kegg:masi', 'ncbi_gene_id:127428605', 'ncbi_protein_id:XP_051533005']
# masi:127441408
# ['kegg:masi', 'ncbi_gene_id:127441408', 'ncbi_protein_id:XP_051554762']
# masi:127448712
# ['kegg:masi', 'ncbi_gene_id:127448712', 'ncbi_protein_id:XP_051567419']
# masi:127442576
# ['kegg:masi', 'ncbi_gene_id:127442576', 'ncbi_protein_id:XP_051556674']
# tros:130569764
# ['kegg:tros', 'ncbi_gene_id:130569764', 'ncbi_protein_id:XP_057215591']
# tros:130569862
# ['kegg:tros', 'ncbi_gene_id:130569862', 'ncbi_protein_id:XP_057215743']
# tros:130545767
# ['kegg:tros', 'ncbi_gene_id:130545767', 'ncbi_protein_id:XP_057176486']
# tros:130554845
# ['kegg:tros', 'ncbi_gene_id:130554845', 'ncbi_protein_id:XP_057190698']
# tdw:130412188
# ['kegg:tdw', 'ncbi_gene_id:130412188', 'ncbi_protein_id:XP_056593339']
# tdw:130407954
# ['kegg:tdw', 'ncbi_gene_id:130407954', 'ncbi_protein_id:XP_056587293']
# tdw:130408224
# ['kegg:tdw', 'ncbi_gene_id:130408224', 'ncbi_protein_id:XP_056587689']
# tdw:130418239
# ['kegg:tdw', 'ncbi_gene_id:130418239', 'ncbi_protein_id:XP_056600246']
# manu:129423823
# ['kegg:manu', 'ncbi_gene_id:129423823', 'ncbi_protein_id:XP_055036280']
# ...
# lue:DCD74_09780
# ['kegg:lue', 'ncbi_gene_id:DCD74_09780', 'ncbi_protein_id:AXA84929', 'uniprot_id:A0A344J7B9']
# lyj:FKV23_15990
# ['kegg:lyj', 'ncbi_gene_id:FKV23_15990', 'ncbi_protein_id:QDH71426', 'uniprot_id:A0A514BVL0']
# lsol:GOY17_00695
# ['kegg:lsol', 'ncbi_gene_id:GOY17_00695', 'ncbi_protein_id:QGW63570']
# lsx:H8B22_06965
# ['kegg:lsx', 'ncbi_gene_id:H8B22_06965', 'ncbi_protein_id:QNP41927', 'uniprot_id:A0A7H0G0W1']
# lare:HIV01_014410
# ['kegg:lare', 'ncbi_gene_id:HIV01_014410', 'ncbi_protein_id:QSX74369']
# lhx:LYSHEL_13500
# ['kegg:lhx', 'ncbi_gene_id:LYSHEL_13500', 'ncbi_protein_id:BCT95479']
# lcas:LYSCAS_13500
# ['kegg:lcas', 'ncbi_gene_id:LYSCAS_13500', 'ncbi_protein_id:BCT92326']
# lcic:INQ41_00400
# ['kegg:lcic', 'ncbi_gene_id:INQ41_00400', 'ncbi_protein_id:QOW19600', 'uniprot_id:A0A7S6UFZ2']
# lavi:INQ42_00400
# ['kegg:lavi', 'ncbi_gene_id:INQ42_00400', 'ncbi_protein_id:QOW22132']
# llz:LYB30171_02553
# ['kegg:llz', 'ncbi_gene_id:LYB30171_02553', 'ncbi_protein_id:CAG4978046']
# laux:LA521A_36310
# ['kegg:laux', 'ncbi_gene_id:LA521A_36310', 'ncbi_protein_id:BDU18430']
# lya:RDV84_07760
# ['kegg:lya', 'ncbi_gene_id:RDV84_07760', 'ncbi_protein_id:WMT04720']
# lum:CNR27_02385
# ['kegg:lum', 'ncbi_gene_id:CNR27_02385', 'ncbi_protein_id:ATD66440', 'uniprot_id:A0A290XBE9']
# lus:E5843_01010
# ['kegg:lus', 'ncbi_gene_id:E5843_01010', 'ncbi_protein_id:QCU72326']
# lug:FPZ22_06925
# ['kegg:lug', 'ncbi_gene_id:FPZ22_06925', 'ncbi_protein_id:QDW66656', 'uniprot_id:A0A518N405']
# lfx:LU699_09025
# ['kegg:lfx', 'ncbi_gene_id:LU699_09025', 'ncbi_protein_id:UHH08474']
# luj:BGP89_04425
# ['kegg:luj', 'ncbi_gene_id:BGP89_04425', 'ncbi_protein_id:AOH35695']
# thes:FHQ07_08190
# ['kegg:thes', 'ncbi_gene_id:FHQ07_08190', 'ncbi_protein_id:QDA57292', 'uniprot_id:A0A5B7ZU17']
# theh:G7079_00835
# ['kegg:theh', 'ncbi_gene_id:G7079_00835', 'ncbi_protein_id:QIL19395', 'uniprot_id:A0A6G7ZRL5']
# tcn:H9L16_05770
# ['kegg:tcn', 'ncbi_gene_id:H9L16_05770', 'ncbi_protein_id:QNN71075', 'uniprot_id:A0A7G9STA0']
# tbv:H9L17_07500
# ['kegg:tbv', 'ncbi_gene_id:H9L17_07500', 'ncbi_protein_id:QNN47956', 'uniprot_id:A0A7G9QX81']
# xbc:ELE36_01110
# ['kegg:xbc', 'ncbi_gene_id:ELE36_01110', 'ncbi_protein_id:QBB69091', 'uniprot_id:A0A411HF35']
# xbc:ELE36_01130
# ['kegg:xbc', 'ncbi_gene_id:ELE36_01130', 'ncbi_protein_id:QBB69095', 'uniprot_id:A0A411HF27']
# fau:Fraau_3258
# ['kegg:fau', 'ncbi_gene_id:Fraau_3258', 'ncbi_protein_id:AFC87581', 'uniprot_id:H8L273']
# fsg:LQ771_14730
# ['kegg:fsg', 'ncbi_gene_id:LQ771_14730', 'ncbi_protein_id:UGB38042']
# fed:LQ772_16550
# ['kegg:fed', 'ncbi_gene_id:LQ772_16550', 'ncbi_protein_id:UGB45562']
# rhd:R2APBS1_0079
# ['kegg:rhd', 'ncbi_gene_id:R2APBS1_0079', 'ncbi_protein_id:AGG87264', 'uniprot_id:M4NA53']
# rgl:CS053_00170
# ['kegg:rgl', 'ncbi_gene_id:CS053_00170', 'ncbi_protein_id:QEE23083', 'uniprot_id:A0A5B9DUA8']
# rth:LRK53_00320
# ['kegg:rth', 'ncbi_gene_id:LRK53_00320', 'ncbi_protein_id:UJJ54886']
# dji:CH75_20625
# ['kegg:dji', 'ncbi_gene_id:CH75_20625', 'ncbi_protein_id:AHX15358']
# dja:HY57_03000
# ['kegg:dja', 'ncbi_gene_id:HY57_03000', 'ncbi_protein_id:AIF46293', 'uniprot_id:A0A075K230']
# dtx:ATSB10_29990
# ['kegg:dtx', 'ncbi_gene_id:ATSB10_29990', 'ncbi_protein_id:AND70453', 'uniprot_id:A0A160N3A9']
# dye:EO087_12045
# ['kegg:dye', 'ncbi_gene_id:EO087_12045', 'ncbi_protein_id:QAU24632', 'uniprot_id:A0A410UK99']
# dcs:ISN74_20240
# ['kegg:dcs', 'ncbi_gene_id:ISN74_20240', 'ncbi_protein_id:QRN53694']
# dtl:H8F01_10285
# ['kegg:dtl', 'ncbi_gene_id:H8F01_10285', 'ncbi_protein_id:QNK03460', 'uniprot_id:A0A7G8Q9K2']
# dta:DYST_03025
# ['kegg:dta', 'ncbi_gene_id:DYST_03025', 'ncbi_protein_id:ULU26081']
# dko:I596_3683
# ['kegg:dko', 'ncbi_gene_id:I596_3683', 'ncbi_protein_id:ANB19666', 'uniprot_id:A0A167HA26']
# lrz:BJI69_06570
# ['kegg:lrz', 'ncbi_gene_id:BJI69_06570', 'ncbi_protein_id:APG03604', 'uniprot_id:A0A0G9HGD0']
# lpy:FIV34_00810
# ['kegg:lpy', 'ncbi_gene_id:FIV34_00810', 'ncbi_protein_id:QDE37843', 'uniprot_id:A0A4Y5Z068']
# lanh:KR767_06215
# ['kegg:lanh', 'ncbi_gene_id:KR767_06215', 'ncbi_protein_id:URX63648']
# lfl:IM816_18215
# ['kegg:lfl', 'ncbi_gene_id:IM816_18215', 'ncbi_protein_id:URL58489']
# laeg:L2Y94_00505
# ['kegg:laeg', 'ncbi_gene_id:L2Y94_00505', 'ncbi_protein_id:UPG85879']
# laeo:L2Y97_00760
# ['kegg:laeo', 'ncbi_gene_id:L2Y97_00760', 'ncbi_protein_id:UPG94667']
# laes:L2Y96_00645
# ['kegg:laes', 'ncbi_gene_id:L2Y96_00645', 'ncbi_protein_id:UPG90311']
# xba:C7S18_17040
# ['kegg:xba', 'ncbi_gene_id:C7S18_17040', 'ncbi_protein_id:AVP98782', 'uniprot_id:A0A2P1PVD0']
# xba:C7S18_04295
# ['kegg:xba', 'ncbi_gene_id:C7S18_04295', 'ncbi_protein_id:AVP96462', 'uniprot_id:A0A2P1PNP2']
# xba:C7S18_04305
# ['kegg:xba', 'ncbi_gene_id:C7S18_04305', 'ncbi_protein_id:AVP96464', 'uniprot_id:A0A2P1PNN7']
# xba:C7S18_09995
# ['kegg:xba', 'ncbi_gene_id:C7S18_09995', 'ncbi_protein_id:AVP97505', 'uniprot_id:A0A2P1PRQ3']
# rbd:ALSL_0040
# ['kegg:rbd', 'ncbi_gene_id:ALSL_0040', 'ncbi_protein_id:BBD78719', 'uniprot_id:A0A2Z6E2A7']
# tamn:N4264_01165
# ['kegg:tamn', 'ncbi_gene_id:N4264_01165', 'ncbi_protein_id:UXI68287']
# vch:VC_2746
# ['kegg:vch', 'ncbi_gene_id:VC_2746', 'ncbi_protein_id:AAF95885', 'uniprot_id:Q9KNJ2']
# vcf:IR04_18775
# ['kegg:vcf', 'ncbi_gene_id:IR04_18775', 'ncbi_protein_id:AKA01125']
# vcs:MS6_2461
# ['kegg:vcs', 'ncbi_gene_id:MS6_2461', 'ncbi_protein_id:BAP04116']
# vce:Vch1786_I2240
# ['kegg:vce', 'ncbi_gene_id:Vch1786_I2240', 'ncbi_protein_id:AET27824']
# vcq:EN18_16725
# ['kegg:vcq', 'ncbi_gene_id:EN18_16725', 'ncbi_protein_id:AIT30665', 'uniprot_id:A0A085SVL7']
# vcj:VCD_001622
# ['kegg:vcj', 'ncbi_gene_id:VCD_001622', 'ncbi_protein_id:ACQ59791']
# vci:O3Y_13135
# ['kegg:vci', 'ncbi_gene_id:O3Y_13135', 'ncbi_protein_id:AFC59497']
# vco:VC0395_A2318
# ['kegg:vco', 'ncbi_gene_id:VC0395_A2318', 'ncbi_protein_id:ABQ20344', 'uniprot_id:A0A0H3AJM3']
# vcr:VC395_2858
# ['kegg:vcr', 'ncbi_gene_id:VC395_2858', 'ncbi_protein_id:ACP10842']
# vcm:VCM66_2666
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/opt/anaconda3/envs/chemicalrxn/lib/python3.11/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/opt/anaconda3/envs/chemicalrxn/lib/python3.11/site-packages/urllib3/util/connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~/opt/anaconda3/envs/chemicalrxn/lib/python3.11/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# TimeoutError: [Errno 60] Operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File ~/opt/anaconda3/envs/chemicalrxn/lib/python3.11/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/opt/anaconda3/envs/chemicalrxn/lib/python3.11/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~/opt/anaconda3/envs/chemicalrxn/lib/python3.11/site-packages/urllib3/connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#
# File ~/opt/anaconda3/envs/chemicalrxn/lib/python3.11/site-packages/urllib3/connection.py:363, in HTTPSConnection.connect(self)
#     361 def connect(self):
#     362     # Add certificate verification
# --> 363     self.sock = conn = self._new_conn()
#     364     hostname = self.host
#
# File ~/opt/anaconda3/envs/chemicalrxn/lib/python3.11/site-packages/urllib3/connection.py:179, in HTTPConnection._new_conn(self)
#     178 except SocketTimeout:
# --> 179     raise ConnectTimeoutError(
#     180         self,
#     181         "Connection to %s timed out. (connect timeout=%s)"
#     182         % (self.host, self.timeout),
#     183     )
#     185 except SocketError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPSConnection object at 0x12ec29bd0>, 'Connection to rest.kegg.jp timed out. (connect timeout=None)')
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/opt/anaconda3/envs/chemicalrxn/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~/opt/anaconda3/envs/chemicalrxn/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File ~/opt/anaconda3/envs/chemicalrxn/lib/python3.11/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='rest.kegg.jp', port=443): Max retries exceeded with url: /conv/uniprot/vcm:VCM66_2666 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x12ec29bd0>, 'Connection to rest.kegg.jp timed out. (connect timeout=None)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 sequences_from_kegg = get_gene_sequences_from_kegg_reaction(all_refs_in_all_rules[rule_id]['kegg'], rule_id)
#
# Cell In[38], line 91, in get_gene_sequences_from_kegg_reaction(all_kegg_ids, rule_id)
#      89 print(gene_id)
#      90 ncbi_protein_id = get_ncbi_protein_id(gene_id)
# ---> 91 uniprot_id = get_uniprot_id(gene_id)
#      92 if ncbi_protein_id!='Nothing':
#      93     record.append("ncbi_protein_id:"+ncbi_protein_id.split(':')[1])
#
# Cell In[4], line 5, in get_uniprot_id(kegg_gene_id)
#       3 get_conv_url = f"{base_url}/conv/uniprot/{kegg_gene_id}"
#       4 #ncbi_protein_ids = []
# ----> 5 response = requests.get(get_conv_url)
#       6 if response.status_code != 200:
#       7     #print(f"Conversoin of Kegg ID to NCBI gene id failed (status code: {response.status_code})")
#       8     gene_id=kegg_gene_id.split(':')[1]
#
# File ~/opt/anaconda3/envs/chemicalrxn/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/opt/anaconda3/envs/chemicalrxn/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/opt/anaconda3/envs/chemicalrxn/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/opt/anaconda3/envs/chemicalrxn/lib/python3.11/site-packages/requests/sessions.py:725, in Session.send(self, request, **kwargs)
#     722 if allow_redirects:
#     723     # Redirect resolving generator.
#     724     gen = self.resolve_redirects(r, request, **kwargs)
# --> 725     history = [resp for resp in gen]
#     726 else:
#     727     history = []
#
# File ~/opt/anaconda3/envs/chemicalrxn/lib/python3.11/site-packages/requests/sessions.py:725, in <listcomp>(.0)
#     722 if allow_redirects:
#     723     # Redirect resolving generator.
#     724     gen = self.resolve_redirects(r, request, **kwargs)
# --> 725     history = [resp for resp in gen]
#     726 else:
#     727     history = []
#
# File ~/opt/anaconda3/envs/chemicalrxn/lib/python3.11/site-packages/requests/sessions.py:266, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263     yield req
#     264 else:
# --> 266     resp = self.send(
#     267         req,
#     268         stream=stream,
#     269         timeout=timeout,
#     270         verify=verify,
#     271         cert=cert,
#     272         proxies=proxies,
#     273         allow_redirects=False,
#     274         **adapter_kwargs,
#     275     )
#     277     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     279     # extract redirect url, if any, for the next loop
#
# File ~/opt/anaconda3/envs/chemicalrxn/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/opt/anaconda3/envs/chemicalrxn/lib/python3.11/site-packages/requests/adapters.py:507, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     504 if isinstance(e.reason, ConnectTimeoutError):
#     505     # TODO: Remove this in 3.0.0: see #2811
#     506     if not isinstance(e.reason, NewConnectionError):
# --> 507         raise ConnectTimeout(e, request=request)
#     509 if isinstance(e.reason, ResponseError):
#     510     raise RetryError(e, request=request)
#
# ConnectTimeout: HTTPSConnectionPool(host='rest.kegg.jp', port=443): Max retries exceeded with url: /conv/uniprot/vcm:VCM66_2666 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x12ec29bd0>, 'Connection to rest.kegg.jp timed out. (connect timeout=None)'))

# %%
 with open("MNXR100024_genes_kegg.json", "w") as outfile:
        json.dump({"MNXR100024":sequences_from_kegg}, outfile)
